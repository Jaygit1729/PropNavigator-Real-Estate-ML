# %% [markdown]
# # 📈 Insight Module — Pricing Intelligence
#
# Turns the deployed price model into **decision support**, not just a black box:
#
# 1. **Price Impact Simulator** — what does +area, +BHK, a pool, a corner plot, more parking do to
#    the price? Computed by **re-running the real model** (baseline vs modified) → true ₹/% deltas.
# 2. **Sector premiums** — the same property priced across every sector → where location costs most.
# 3. **Society premiums** — the brand/quality premium of each society, measured from **observed
#    listings** (₹/sqft), not from the model. See note below.
# 4. **SHAP** — global price drivers + a per-property "why this price" breakdown.
#
# **Why model-simulation, not regression coefficients.** The old module read coefficients from a
# separate Ridge proxy; with collinear distance features those are unstable. Re-running the actual
# deployed model gives **model-true, non-linear** impacts — the numbers you'd actually get.
#
# **Why society premiums are NOT model-derived.** `society` was dropped from the model: it can't be
# obtained at prediction time (users don't know it), so serving it meant guessing it from the sector —
# correct only ~31% of the time — which made production accuracy *worse* (14.29% vs 11.18% MAPE).
# See `notebooks/error_analysis/society_ablation.ipynb`. The model therefore has no opinion on society
# at all, so premiums are computed straight from the data: a society's median ₹/sqft vs the Gurgaon
# median. That's an **observed market fact** rather than a model opinion — a stronger claim anyway.
#
# **Self-contained** (no `src` imports, no file logging). Precomputes to `data/insight_module/`:
# `sector_reference.csv`, `type_reference.csv`, `sector_premiums.csv`, `society_premiums.csv`,
# `shap_global_importance.csv`.

# %%
import os, warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import joblib
import shap
import plotly.express as px
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
OUT = '../../data/insight_module'
os.makedirs(OUT, exist_ok=True)

df = pd.read_csv('../../data/fs/feature_selected_properties.csv')
bundle = joblib.load('../../artifacts/best_model.joblib')
pipeline = bundle['pipeline']
residual_q = bundle.get('residual_quantiles', {})
TARGET = 'price_in_cr'
FEATURES = [c for c in df.columns if c != TARGET]
DIST = ['dist_to_cyber_city', 'dist_to_golf_road', 'dist_to_airport', 'dist_to_manesar']
print('model:', bundle['model_name'], '| MAPE %:', bundle['test_mape_percent'])

# %% [markdown]
# ## 1. Feature assembly (shared by every section)
#
# `build_input_row` assembles the 24 model features from a compact input dict, deriving the four
# landmark distances from a per-sector reference. `predict` inverse-transforms the log target.
#
# Note the distances are a *geographic fact* of the sector the user already picked — unlike `society`,
# which would have been a guessed identity. That distinction is why the distances stay and society goes.

# %%
# sector_ref holds only the four median distances now — `society` is no longer a
# model feature, so there is nothing to look up for it.
sector_ref = df.groupby('sector').agg(**{d: (d, 'median') for d in DIST}).reset_index()
sector_ref.to_csv(f'{OUT}/sector_reference.csv', index=False)

# per-property-type defaults for the fields we DON'T ask in the simulator (floors, balcony)
type_ref = df.groupby('property_type').agg(
    total_floor=('total_floor', 'median'), balcony=('balcony', 'median'),
    floornum_category=('floornum_category', lambda x: x.mode().iloc[0])).reset_index()
type_ref.to_csv(f'{OUT}/type_reference.csv', index=False)
print('saved sector_reference.csv', sector_ref.shape, '| type_reference.csv', type_ref.shape)

CONST = dict(facing='unknown', open_parking=0.0, ov_main_road=0, ov_others=0)

def build_input_row(inp, ref, features=FEATURES):
    r = ref.loc[ref['sector'] == inp['sector']]
    tr = type_ref.loc[type_ref['property_type'] == inp['property_type']]
    tr = tr.iloc[0] if not tr.empty else type_ref.iloc[0]
    covered = float(inp.get('covered_parking', 1))
    total_floor = float(inp['total_floor']) if inp.get('total_floor') is not None else float(tr['total_floor'])
    row = {
        'area': float(inp['area']), 'total_floor': total_floor,
        'bathroom': int(inp['bathroom']), 'property_type': inp['property_type'],
        'covered_parking': covered, 'open_parking': CONST['open_parking'],
        'sector': inp['sector'], 'bedRoom': int(inp['bedRoom']),
        'furnishing': inp.get('furnishing', 'semi-furnished'), 'balcony': float(tr['balcony']),
        'age_possession_category': inp.get('age_possession_category', 'New Property'),
        'facing': CONST['facing'], 'floornum_category': tr['floornum_category'],
    }
    row['total_parking'] = covered + CONST['open_parking']
    for flag in ['has_ac', 'has_power_backup', 'is_corner', 'has_pool']:
        row[flag] = int(inp.get(flag, 0))
    row['ov_main_road'] = CONST['ov_main_road']; row['ov_others'] = CONST['ov_others']
    for d in DIST:
        row[d] = float(r[d].iloc[0]) if not r.empty else float(df[d].median())
    return pd.DataFrame([row])[features]

def predict(inp_or_df):
    input_df = inp_or_df if isinstance(inp_or_df, pd.DataFrame) else build_input_row(inp_or_df, sector_ref)
    return float(np.expm1(pipeline.predict(input_df)[0]))

def predict_many(inps):
    # batch many input dicts into ONE model call (fast — avoids per-row overhead)
    batch = pd.concat([build_input_row(i, sector_ref) for i in inps], ignore_index=True)
    return np.expm1(pipeline.predict(batch))

# baseline = just the essentials; floors/balcony/facing derived like the price estimator
BASELINE = dict(property_type='Flat', sector='sector 49', area=1500, bedRoom=3, bathroom=2,
                furnishing='semi-furnished', age_possession_category='New Property',
                covered_parking=1, has_ac=1, has_power_backup=1)
print('baseline price: ₹%.2f Cr' % predict(BASELINE))

# %% [markdown]
# ## 2. Price Impact Simulator (what-if)
#
# Each lever = predict(baseline with the change) − predict(baseline). Model-true, non-linear.

# %%
def impact(change: dict, label: str):
    base = predict(BASELINE)
    new = predict({**BASELINE, **change})
    pct = (new / base - 1) * 100
    return {'Change': label, 'New Price (Cr)': round(new, 2),
            'Δ (Cr)': round(new - base, 2), 'Δ (%)': round(pct, 1)}

scenarios = [
    impact({'area': BASELINE['area'] + 500}, '+500 sqft area'),
    impact({'bedRoom': BASELINE['bedRoom'] + 1, 'bathroom': BASELINE['bathroom'] + 1}, '+1 BHK (+bath)'),
    impact({'has_pool': 1}, 'Add swimming pool'),
    impact({'is_corner': 1}, 'Corner property'),
    impact({'covered_parking': BASELINE['covered_parking'] + 1}, '+1 covered parking'),
    impact({'furnishing': 'furnished'}, 'Upgrade to furnished'),
    impact({'age_possession_category': 'Under Construction'}, 'Under construction'),
]
sim = pd.DataFrame(scenarios)
base_price = predict(BASELINE)
print(f'Baseline: ₹{base_price:.2f} Cr (Flat, sector 49, 1500 sqft, 3 BHK)')
sim

# %%
fig = px.bar(sim.sort_values('Δ (%)'), x='Δ (%)', y='Change', orientation='h',
             color='Δ (%)', color_continuous_scale='RdYlGn', color_continuous_midpoint=0,
             labels={'Δ (%)': 'Price impact (%)', 'Change': ''}, title='What-if price impact vs baseline')
fig.update_layout(height=430, coloraxis_showscale=False)
fig

# %% [markdown]
# > **Conclusion.** Impacts are economically sensible — more area and an extra BHK add the most;
# > amenities add modest premiums. Because these come from the real model they capture non-linear,
# > context-dependent effects a single coefficient can't.

# %% [markdown]
# ## 3. Sector premiums — same property, every sector
#
# Hold the baseline fixed, swap only the sector (its four landmark distances come along),
# predict, and rank vs the median sector.
#
# This one **stays model-derived**, because `sector` is still a model feature and the user tells us
# the sector directly — no guessing involved.

# %%
base_no_sector = {k: v for k, v in BASELINE.items() if k != 'sector'}
all_sectors = list(sector_ref['sector'])
prices = predict_many([{**base_no_sector, 'sector': s} for s in all_sectors])
sec_prem = pd.DataFrame({'sector': all_sectors, 'price_cr': prices})
med = sec_prem['price_cr'].median()
sec_prem['premium_pct'] = ((sec_prem['price_cr'] / med - 1) * 100).round(1)
sec_prem = sec_prem.sort_values('premium_pct', ascending=False).reset_index(drop=True)
sec_prem.to_csv(f'{OUT}/sector_premiums.csv', index=False)
print('saved sector_premiums.csv | median sector price ₹%.2f Cr' % med)

top = sec_prem.head(12).sort_values('premium_pct')
fig = px.bar(top, x='premium_pct', y='sector', orientation='h', color='premium_pct',
             color_continuous_scale='Tealgrn', labels={'premium_pct': 'Premium vs median (%)', 'sector': ''},
             title='Top sectors by price premium (same property)')
fig.update_layout(height=450, coloraxis_showscale=False)
fig

# %% [markdown]
# > **Conclusion.** The premium sectors are the Golf-Course-Road / Cyber-City corridor — the
# > exact same flat costs far more there than in the periphery. This isolates the pure location
# > premium, holding the property constant.

# %% [markdown]
# ## 4. Society premiums — the brand effect (measured, not modelled)
#
# The model has no `society` feature, so it cannot have an opinion here — asking it to price the same
# unit "in Camellias vs elsewhere" would return the identical number every time. So we measure the
# premium **directly from the listings** instead.
#
# **Metric: median ₹/sqft, not median price.** Ranking by raw price would mostly reveal *which
# societies have bigger flats*. Dividing by area normalises size away, so what remains is the
# brand/quality signal:
#
# $$\text{premium\_pct} = \left(\frac{\text{society median ₹/sqft}}{\text{overall median ₹/sqft}} - 1\right) \times 100$$
#
# We read from `data/pp/preprocessed_properties.csv` — the feature-selected file no longer carries
# `society`, but the preprocessed file still has every column. Societies need ≥30 listings to qualify,
# and the `other` bucket (rare societies grouped during preprocessing) is excluded.

# %%
MIN_LISTINGS = 30

# The fs file has no society column any more — step back to the preprocessed file.
pp = pd.read_csv('../../data/pp/preprocessed_properties.csv')
pp['ppsf'] = pp['price_in_cr'] / pp['area']          # normalise away unit size
pp = pp[pp['society'] != 'other']                     # a bucket of rare societies, not a real one

overall_median_ppsf = pp['ppsf'].median()

g = pp.groupby('society').agg(
    listings=('ppsf', 'size'),
    median_ppsf=('ppsf', 'median'),
    price_cr=('price_in_cr', 'median'),
)
g = g[g['listings'] >= MIN_LISTINGS].copy()
g['premium_pct'] = ((g['median_ppsf'] / overall_median_ppsf) - 1) * 100

soc_prem = (g.reset_index()[['society', 'price_cr', 'premium_pct']]
              .sort_values('premium_pct', ascending=False)
              .round({'premium_pct': 1})
              .reset_index(drop=True))
soc_prem.to_csv(f'{OUT}/society_premiums.csv', index=False)
print(f'saved society_premiums.csv | {len(soc_prem)} societies (>={MIN_LISTINGS} listings)')
print('overall median ₹/sqft: %.0f' % (overall_median_ppsf * 1e7))

top = soc_prem.head(12).sort_values('premium_pct')
fig = px.bar(top, x='premium_pct', y='society', orientation='h', color='premium_pct',
             color_continuous_scale='Purp', labels={'premium_pct': 'Premium vs median (%)', 'society': ''},
             title='Top societies by observed ₹/sqft premium')
fig.update_layout(height=450, coloraxis_showscale=False)
fig

# %% [markdown]
# > **Conclusion.** The top societies are the recognised luxury projects — DLF Camellias commands
# > roughly **6×** the median ₹/sqft in Gurgaon. Note the spread here is far wider than the old
# > model-derived version produced (which compressed everything into ±100%): tree models regress
# > toward the mean and had few ultra-luxury examples to learn from, so they *understated* the real
# > premium. Measuring it directly from listings is both simpler and more truthful.
# >
# > **The wider lesson:** `society` is excellent for *describing* the market and useless for
# > *predicting* an unknown property — precisely because you can't know it at prediction time. The
# > feature belongs in analytics, not in the model.

# %% [markdown]
# ## 5. SHAP — global drivers & 'why this price'
#
# SHAP runs **directly on the deployed LightGBM** (ordinal encoding is 1:1, so it maps back to real
# feature names). Global = mean |SHAP|; local = additive per-feature decomposition of one property's price.
#
# Previously the deployed model was a stacking ensemble and we had to reach inside it to pull out a
# tree base to explain. Shipping a single model removed that awkwardness — a real, if secondary,
# benefit of dropping stacking: **the thing you serve is the thing you explain.**

# %%
# The deployed model IS a LightGBM Pipeline now, so explain it directly —
# no need to dig a base estimator out of a stacking ensemble.
pre = pipeline.named_steps['preprocessor']; reg = pipeline.named_steps['regressor']
feat_names = [f.split('__')[-1] for f in pre.get_feature_names_out()]
X = df[FEATURES]; X_ord = X[feat_names]
explainer = shap.TreeExplainer(reg)

rng = np.random.RandomState(42)
idx = rng.choice(len(X), 3000, replace=False)
sv = explainer.shap_values(pre.transform(X.iloc[idx]))
global_imp = (pd.Series(np.abs(sv).mean(0), index=feat_names).sort_values(ascending=False)
              .rename('mean_abs_shap').reset_index().rename(columns={'index': 'feature'}))
global_imp.to_csv(f'{OUT}/shap_global_importance.csv', index=False)

top = global_imp.head(15).sort_values('mean_abs_shap')
fig = px.bar(top, x='mean_abs_shap', y='feature', orientation='h', color='mean_abs_shap',
             color_continuous_scale='Blues', labels={'mean_abs_shap': 'Mean |SHAP| (log-price)', 'feature': ''},
             title='Global price drivers (SHAP)')
fig.update_layout(height=520, coloraxis_showscale=False)
fig

# %%
# local 'why this price' for one property
i = 100
sv_one = explainer.shap_values(pre.transform(X.iloc[[idx[i]]]))[0]
base_val = float(np.ravel(explainer.expected_value)[0])
contrib = (pd.DataFrame({'feature': feat_names, 'value': X_ord.iloc[idx[i]].values,
                         'pct_effect': (np.exp(sv_one) - 1) * 100})
             .reindex(np.argsort(np.abs(sv_one))[::-1]).head(10))
print('actual ₹%.2f Cr | predicted ₹%.2f Cr' % (df[TARGET].iloc[idx[i]], np.expm1(base_val + sv_one.sum())))
fig = px.bar(contrib[::-1], x='pct_effect', y='feature', orientation='h', color='pct_effect',
             color_continuous_scale='RdYlGn', color_continuous_midpoint=0,
             labels={'pct_effect': 'Price effect (%)', 'feature': ''}, title='Why the model priced this home')
fig.update_layout(height=430, coloraxis_showscale=False)
fig

# %% [markdown]
# > **Conclusion.** Global: `area` and the engineered distances dominate; amenity flags are weak
# > (Simpson's paradox). Local: any single valuation breaks into additive, model-true contributions.
# > Note `society` no longer appears at all — it isn't a feature any more, which is exactly right.
#
# ---
# ### Summary
# The Insight module leads with **actionable tools** — a what-if simulator and sector premium
# rankings computed **live from the deployed LightGBM**, society premiums **measured directly from
# listings**, and **SHAP** for global drivers and per-property explanations.
#
# Each number is sourced honestly: the model answers questions it can actually answer (given inputs
# a user can supply), and the data answers the rest. Artifacts land in `data/insight_module/`;
# `pages/Insight_Module.py` renders them (premiums static, simulator + local SHAP computed live).
