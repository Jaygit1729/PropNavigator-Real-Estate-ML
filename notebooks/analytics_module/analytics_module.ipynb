# %% [markdown]
# # 📊 Analytics Module — Gurgaon Real Estate
#
# **Purpose.** Turn the cleaned property data into market intelligence: supply structure, price
# volatility, configuration trends, and value dynamics across Gurgaon sectors. This notebook is
# the **validation surface** for `pages/Analytics_Module.py` — the same charts, so you can check
# every visual before it ships.
#
# **Self-contained.** All logic lives in this notebook (no `src` imports, no file logging). It reads
# the feature-engineering output, applies the **same outlier rules as the model** (kept inline so
# this notebook stands alone), and writes one artifact: `data/analytics_module/analytics_base.csv`.
#
# **Data-source decision.** We build off `data/fe/featured_properties.csv` — the only frame that
# still carries the columns the model drops but analytics needs: `latitude`, `longitude`,
# `price_per_sqft`, and the raw `features` amenity list.

# %%
import ast
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
from wordcloud import WordCloud

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Build the analytics base
#
# Outlier rules mirror `src/data_preprocessing/pre_process_data.py` (the model's cleaning) so
# analytics shows the **same clean population as the model** — errors removed, genuine luxury kept.

# %%
# --- outlier rules (mirror of the model's preprocessing; inlined so this notebook is standalone) ---
AREA_MIN = 180
AREA_CAP = {'Flat': 16000, 'Independent Builder Floor': 10000, 'Independent House': 30000}
PPSF_MIN, PPSF_MAX = 1500, 250000
MIN_AREA_PER_BEDROOM = 150

# Gurgaon bounding box — anything outside is a bad geocode (won't plot on the map)
LAT_MIN, LAT_MAX = 28.30, 28.60
LON_MIN, LON_MAX = 76.80, 77.20

def parse_features(v):
    if pd.isna(v):
        return []
    try:
        x = ast.literal_eval(v)
        return [str(a).strip() for a in x] if isinstance(x, list) else []
    except (ValueError, SyntaxError):
        return []

df = pd.read_csv('../../data/fe/featured_properties.csv')
n0 = len(df)

# univariate + bivariate outlier removal (same bands as the model)
df = df[(df['area'] >= AREA_MIN) & (df['area'] <= df['property_type'].map(AREA_CAP))]
implied_ppsf = df['price_in_cr'] * 1e7 / df['area']
df = df[implied_ppsf.between(PPSF_MIN, PPSF_MAX)]
df = df[(df['area'] / df['bedRoom']) >= MIN_AREA_PER_BEDROOM]

# null out out-of-box coordinates (kept rows, just won't plot)
in_box = df['latitude'].between(LAT_MIN, LAT_MAX) & df['longitude'].between(LON_MIN, LON_MAX)
df.loc[~in_box, ['latitude', 'longitude']] = np.nan

# null-free implied price_per_sqft, consistent with the outlier band above
df['price_per_sqft'] = (df['price_in_cr'] * 1e7 / df['area']).round(0)

KEEP = ['property_type', 'society', 'sector', 'price_in_cr', 'price_per_sqft', 'area',
        'bedRoom', 'bathroom', 'balcony', 'latitude', 'longitude', 'features',
        'dist_to_cyber_city', 'dist_to_golf_road', 'dist_to_airport', 'dist_to_manesar']
df = df[KEEP].reset_index(drop=True)

print(f'raw FE rows: {n0:,}  ->  clean analytics base: {len(df):,}')
print('property types :', df.property_type.value_counts().to_dict())
print('sectors        :', df.sector.nunique())
print('price (Cr)     :', round(df.price_in_cr.min(), 2), '->', round(df.price_in_cr.max(), 2))
print('ppsf           :', df.price_per_sqft.min(), '->', df.price_per_sqft.max())
df.head(3)

# %% [markdown]
# > **Conclusion.** ~39k clean listings across 131 sectors. Flats dominate supply (~73%),
# > builder floors ~23%, independent houses ~4%. Prices span ₹0.12 → ₹150 Cr — the luxury tail is
# > kept on purpose; only physically impossible rows were dropped.

# %% [markdown]
# ## 2. Save the artifact (for the Streamlit page)

# %%
import os
os.makedirs('../../data/analytics_module', exist_ok=True)
df.to_csv('../../data/analytics_module/analytics_base.csv', index=False)
print('saved data/analytics_module/analytics_base.csv', df.shape)

# %% [markdown]
# ## 3. Market Structure — property mix by sector

# %%
sector_total = df.groupby('sector').size().reset_index(name='total_listings')
sector_mix = (df.groupby(['sector', 'property_type']).size()
                .reset_index(name='listing_count').merge(sector_total, on='sector'))
sector_mix['pct_of_sector'] = (sector_mix['listing_count'] / sector_mix['total_listings'] * 100).round(1)

fig = px.bar(sector_mix, x='listing_count', y='sector', color='property_type', orientation='h',
             color_discrete_sequence=px.colors.qualitative.Bold,
             labels={'listing_count': 'Listings', 'sector': 'Sector', 'property_type': 'Property Type'})
fig.update_layout(height=1400, yaxis={'categoryorder': 'total ascending'})
fig

# %% [markdown]
# > **Conclusion.** Supply is concentrated — a handful of sectors hold most inventory; the long
# > tail is thin (where the price model has the fewest comparables). Flat-dominant sectors are the
# > new high-rise belts; builder-floor-heavy sectors are the older independent pockets.

# %% [markdown]
# ## 4. Sector Price Dispersion (IQR of ₹/sqft)

# %%
MIN_LISTINGS = 15
disp = (df.groupby('sector')
          .agg(p25=('price_per_sqft', lambda x: x.quantile(0.25)),
               p75=('price_per_sqft', lambda x: x.quantile(0.75)),
               listings=('price_per_sqft', 'count')).reset_index())
disp['iqr'] = disp['p75'] - disp['p25']
disp = disp[disp['listings'] >= MIN_LISTINGS].sort_values('iqr', ascending=False)
fig = px.imshow(disp.set_index('sector')[['iqr']], color_continuous_scale=px.colors.sequential.Magma,
                aspect='auto', labels={'color': 'IQR (₹/sqft)', 'y': 'Sector', 'x': ''})
fig.update_layout(height=800)
fig

# %% [markdown]
# > **Conclusion.** High-IQR sectors are premium/mixed belts where a luxury tower sits next to
# > older stock — a single sector average misleads there, and the model must lean on unit-level
# > features. Low-IQR sectors are homogeneous and easy to price.

# %% [markdown]
# ## 5. Bedroom × Property-Type Configuration

# %%
bhk = df[df['bedRoom'].between(1, 6)]
mat = bhk.groupby(['property_type', 'bedRoom']).size().reset_index(name='count')
mat['pct'] = mat.groupby('property_type')['count'].transform(lambda x: x / x.sum() * 100).round(1)
heat = mat.pivot(index='property_type', columns='bedRoom', values='pct').fillna(0)
fig = px.imshow(heat, text_auto=True, aspect='auto', color_continuous_scale=px.colors.sequential.Viridis,
                labels={'color': '% of Listings', 'x': 'Bedrooms', 'y': 'Property Type'})
fig.update_layout(height=400)
fig

# %% [markdown]
# > **Conclusion.** Flats cluster at 2–3 BHK (end-user demand); builder floors skew 3–4 BHK;
# > independent houses spread heavier into 4+ BHK — the premium, large-format segment (and the one
# > with the highest model error).

# %% [markdown]
# ## 6. Price Distribution by Property Type

# %%
fig = px.violin(df, x='property_type', y='price_in_cr', color='property_type', box=True,
                points='outliers', color_discrete_sequence=px.colors.qualitative.Set2,
                labels={'property_type': 'Property Type', 'price_in_cr': 'Price (Cr)'})
fig.update_layout(height=550, showlegend=False)
fig

# %% [markdown]
# > **Conclusion.** All three types are right-skewed with a heavy luxury tail; independent houses
# > have the widest spread. The tail is exactly why the model trains on `log(price)`.

# %% [markdown]
# ## 7. Area Segment vs Price Efficiency

# %%
AREA_BINS = [0, 1000, 2200, 3500, float('inf')]
AREA_LABELS = ['Small (<1000)', 'Mid (1000-2200)', 'Large (2200-3500)', 'Luxury (3500+)']
seg = df.copy(); seg['area_segment'] = pd.cut(seg['area'], bins=AREA_BINS, labels=AREA_LABELS)
fig = px.box(seg.dropna(subset=['area_segment']), x='area_segment', y='price_per_sqft',
             color='area_segment', color_discrete_sequence=px.colors.qualitative.Set2,
             labels={'area_segment': 'Area Segment', 'price_per_sqft': '₹/sqft'})
fig.update_layout(height=550, showlegend=False)
fig

# %% [markdown]
# > **Conclusion.** ₹/sqft rises with size — the luxury segment commands the highest rate per
# > foot (location + finish premium), not a bulk discount. Size is a genuine value signal.

# %% [markdown]
# ## 8. Geospatial view — sector-level price & size

# %%
geo = (df.dropna(subset=['latitude', 'longitude']).groupby('sector', as_index=False)
         .mean(numeric_only=True)[['sector', 'price_per_sqft', 'area', 'latitude', 'longitude']])
fig = px.scatter_map(geo, lat='latitude', lon='longitude', color='price_per_sqft', size='area',
                     size_max=20, zoom=10.5, map_style='open-street-map', hover_name='sector',
                     color_continuous_scale=px.colors.cyclical.IceFire,
                     labels={'price_per_sqft': 'Avg ₹/sqft', 'area': 'Avg Area'})
fig.update_layout(height=600, margin=dict(l=0, r=0, t=30, b=0))
fig

# %% [markdown]
# > **Conclusion.** A clear price gradient radiates from the Golf-Course-Road / Cyber-City core
# > outward — the same signal the model captures via the engineered `dist_to_*` features.

# %% [markdown]
# ## 9. Common Amenities (word cloud)

# %%
words = []
for lst in df['features'].dropna().apply(parse_features):
    words.extend(lst)
print('total amenity mentions:', len(words))
wc = WordCloud(width=800, height=400, background_color='white').generate(' '.join(words))
plt.figure(figsize=(12, 6)); plt.imshow(wc); plt.axis('off'); plt.title('Common Amenities'); plt.show()

# %% [markdown]
# > **Conclusion.** AC, power backup, Vaastu and visitor parking are near-universal — little
# > price signal (Simpson's paradox). Rarer tags (servant room, club, pool) actually move value.

# %% [markdown]
# ## 10. Area vs Price scatter

# %%
fig = px.scatter(df, x='area', y='price_in_cr', color='bedRoom',
                 color_continuous_scale=px.colors.sequential.Viridis, opacity=0.6,
                 labels={'area': 'Area (Sqft)', 'price_in_cr': 'Price (Cr)', 'bedRoom': 'Bedrooms'})
fig.update_layout(height=600)
fig

# %% [markdown]
# > **Conclusion.** Price scales roughly linearly with area within a bedroom band; isolated high
# > points are genuine luxury outliers. Area is the single strongest driver (importance ~1.0).

# %% [markdown]
# ## 11. Bedroom-wise Price + Distribution

# %%
box = df[df['bedRoom'].between(1, 4)]
fig = px.box(box, x='bedRoom', y='price_in_cr', color='bedRoom',
             color_discrete_sequence=px.colors.qualitative.Set2,
             labels={'bedRoom': 'Bedrooms', 'price_in_cr': 'Price (Cr)'})
fig.update_layout(height=500, showlegend=False)
fig

# %%
pie = df[df['bedRoom'].between(1, 6)]
fig = px.pie(pie, names='bedRoom', hole=0.4, labels={'bedRoom': 'Bedrooms'})
fig.update_layout(height=500, legend_title_text='Bedrooms')
fig

# %% [markdown]
# > **Conclusion.** The market is a 2–3 BHK market — end-user demand drives Gurgaon volume;
# > higher-BHK slices are the premium segment.
#
# ---
# ### Summary
# Market context before the search: where supply is, where pricing is volatile, what configurations
# dominate, and how value moves across geography — all on the same clean population the price model
# uses. The page `pages/Analytics_Module.py` renders these charts interactively from
# `data/analytics_module/analytics_base.csv`.
