# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)

# %% [markdown]
# ### 1. Independent Builder Floor Data Loading

# %%
df_builder_floor= pd.read_csv("../../data/web_scraping/independent_builder_floor.csv")
df_builder_floor
# Out:
#                                           property_name  \
# 0     4 BHK Independent Builder Floor in Sushant Lok...
# 1     4 BHK Independent Builder Floor in Sector 102,...
# 2     4 BHK Independent Builder Floor in A Block Sus...
# 3     4 BHK Independent Builder Floor in DLF Phase 2...
# 4     4 BHK Independent Builder Floor in DLF Phase 2...
# ...                                                 ...
# 1247  4 BHK Independent Builder Floor in Sector 46, ...
# 1248  4 BHK Independent Builder Floor in Sushant Lok...
# 1249  4 BHK Independent Builder Floor in Sushant Lok...
# 1250  4 BHK Independent Builder Floor in Sector 84, ...
# 1251  4 BHK Independent Builder Floor in Sector 63A,...
#
#                                    society     price           area  \
# 0                  Brand New Builder Floor  ₹3.85 Cr  ₹14,259 /sqft
# 1                            BPTP Amstoria   ₹3.4 Cr  ₹17,000 /sqft
# 2     A Block Sushant Lok Phase 1, Gurgaon  ₹3.66 Cr  ₹13,811 /sqft
# 3                     DLF Phase 2, Gurgaon  ₹5.25 Cr  ₹19,444 /sqft
# 4                        PARK FACING FLOOR     ₹5 Cr  ₹12,500 /sqft
# ...                                    ...       ...            ...
# 1247                 Private Builder Floor     ₹3 Cr  ₹10,000 /sqft
# 1248          Sushant Lok 1 Builder Floors     ₹5 Cr  ₹22,727 /sqft
# 1249          Sushant Lok Phase 1, Gurgaon  ₹5.85 Cr  ₹20,892 /sqft
# 1250                      SS Linden Floors  ₹2.92 Cr  ₹10,428 /sqft
# 1251                     Anant Raj Estates   ₹3.8 Cr  ₹15,932 /sqft
#
#                                   areawithtype property_id  \
# 0     2,700 sqft (251 sqm) Super Built-up Area   O85021804
# 1             2,000 sqft (186 sqm) Carpet Area   V85303340
# 2     2,650 sqft (246 sqm) Super Built-up Area   O83672012
# 3             2,700 sqft (251 sqm) Carpet Area   K85623978
# 4             4,000 sqft (372 sqm) Carpet Area   E85624224
# ...                                        ...         ...
# 1247  3,000 sqft (279 sqm) Super Built-up Area   G78860067
# 1248          2,200 sqft (204 sqm) Carpet Area   S85218742
# 1249          2,800 sqft (260 sqm) Carpet Area   R85216914
# 1250        2,800 sqft (260 sqm) Built-up Area   B84531164
# 1251  2,385 sqft (222 sqm) Super Built-up Area   F84618392
#
#                                                    link    bedrooms  \
# 0     https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
# 1     https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
# 2     https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
# 3     https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
# 4     https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
# ...                                                 ...         ...
# 1247  https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
# 1248  https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
# 1249  https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
# 1250  https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
# 1251  https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
#
#         bathrooms       balcony                            additional_room  \
# 0     4 Bathrooms   2 Balconies                               Servant Room
# 1     4 Bathrooms  3+ Balconies                                        NaN
# 2     4 Bathrooms   2 Balconies                                 Study Room
# 3     5 Bathrooms   3 Balconies  Pooja Room,Study Room,Servant Room,Others
# 4     5 Bathrooms   2 Balconies  Pooja Room,Study Room,Servant Room,Others
# ...           ...           ...                                        ...
# 1247  4 Bathrooms   2 Balconies                               Servant Room
# 1248  4 Bathrooms   3 Balconies                               Servant Room
# 1249  4 Bathrooms  3+ Balconies                               Servant Room
# 1250  4 Bathrooms   2 Balconies                               Servant Room
# 1251  4 Bathrooms   3 Balconies                               Servant Room
#
#               floor_info      facing     property_age  \
# 0      2nd   of 4 Floors  North-East  0 to 1 Year Old
# 1      1st   of 4 Floors  North-East  1 to 5 Year Old
# 2      1st   of 4 Floors        East  1 to 5 Year Old
# 3      2nd   of 4 Floors        East  1 to 5 Year Old
# 4      3rd   of 4 Floors        East  0 to 1 Year Old
# ...                  ...         ...              ...
# 1247   1st   of 4 Floors  North-East  0 to 1 Year Old
# 1248  Ground of 4 Floors        West  0 to 1 Year Old
# 1249   2nd   of 4 Floors        East  0 to 1 Year Old
# 1250   2nd   of 4 Floors       North  0 to 1 Year Old
# 1251   4th   of 4 Floors  North-East  0 to 1 Year Old
#
#                                      furnishing_details  \
# 0     ['1 Water Purifier', '6 Fan', '1 Exhaust Fan',...
# 1     ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 2     ['3 Fan', '1 Fridge', '5 Geyser', '1 Stove', '...
# 3     ['1 Water Purifier', '12 Fan', '1 Exhaust Fan'...
# 4     ['11 Wardrobe', '13 Fan', '1 Exhaust Fan', '8 ...
# ...                                                 ...
# 1247  ['8 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1248  ['7 Fan', '1 Exhaust Fan', '5 Geyser', '1 Micr...
# 1249  ['4 Wardrobe', '7 Fan', '1 Exhaust Fan', '6 Ge...
# 1250  ['4 Wardrobe', '4 Geyser', '6 AC', '1 Modular ...
# 1251  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '5 Ge...
#
#                                                features  \
# 0     ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 1     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 2     ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 3     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 4     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# ...                                                 ...
# 1247  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1248  ['Security / Fire Alarm', 'Intercom Facility',...
# 1249  ['Security / Fire Alarm', 'Intercom Facility',...
# 1250  ['Water purifier', 'Centrally Air Conditioned'...
# 1251  ['Security / Fire Alarm', 'Private Garden / Te...
#
#                                         nearby_location
# 0     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 1     ['Conscient One Mall', "Domino's Pizza", 'Daul...
# 2     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 3     ['Gurgaon Central Mall', 'Hanuman Mandir', 'PV...
# 4     ['Gurgaon Central Mall', 'PVR Cinames', 'Priva...
# ...                                                 ...
# 1247  ['Dr. Aruna Kalra', 'Raheja Mall', 'Delhi Publ...
# 1248  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1249  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1250  ['Agri Business Management Collage', 'Manesar ...
# 1251  ['De Adventure Park', 'Vatika Business Centre'...
#
# [1252 rows x 17 columns]

# %%
df_builder_floor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1252 entries, 0 to 1251
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   property_name       1252 non-null   object
#  1   society             1252 non-null   object
#  2   price               1252 non-null   object
#  3   area                1252 non-null   object
#  4   areawithtype        1252 non-null   object
#  5   property_id         1252 non-null   object
#  6   link                1252 non-null   object
#  7   bedrooms            1252 non-null   object
#  8   bathrooms           1252 non-null   object
#  9   balcony             1252 non-null   object
#  10  additional_room     1126 non-null   object
#  11  floor_info          1252 non-null   object
#  12  facing              1185 non-null   object
#  13  property_age        1251 non-null   object
#  14  furnishing_details  1180 non-null   object
#  15  features            1214 non-null   object
#  16  nearby_location     1252 non-null   object
# dtypes: object(17)
# memory usage: 166.4+ KB

# %%
df_builder_floor.describe()
# Out:
#                                             property_name  \
# count                                                1252
# unique                                                205
# top     4 BHK Independent Builder Floor in DLF Phase 1...
# freq                                                   66
#
#                      society    price           area  \
# count                   1252     1252           1252
# unique                   296      273            874
# top     Palam Vihar, Gurgaon  ₹3.5 Cr  ₹13,888 /sqft
# freq                      64       37             13
#
#                                     areawithtype property_id  \
# count                                       1252        1252
# unique                                       374        1252
# top     2,700 sqft (251 sqm) Super Built-up Area   O85021804
# freq                                          74           1
#
#                                                      link    bedrooms  \
# count                                                1252        1252
# unique                                               1252           5
# top     https://www.99acres.com/4-bhk-bedroom-independ...  4 Bedrooms
# freq                                                    1         727
#
#           bathrooms      balcony additional_room         floor_info facing  \
# count          1252         1252            1126               1252   1185
# unique            7            5              65                 33      8
# top     4 Bathrooms  2 Balconies    Servant Room  2nd   of 4 Floors   East
# freq            591          917             223                372    401
#
#            property_age furnishing_details  \
# count              1251               1180
# unique                4               1032
# top     0 to 1 Year Old                 []
# freq                825                 37
#
#                                                  features  \
# count                                                1214
# unique                                                649
# top     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# freq                                                  144
#
#                                           nearby_location
# count                                                1252
# unique                                                618
# top     ['Max, Fortis', 'Pathways', 'Golf Course Road'...
# freq                                                   38

# %%
df_builder_floor.isnull().sum()
# Out:
# property_name           0
# society                 0
# price                   0
# area                    0
# areawithtype            0
# property_id             0
# link                    0
# bedrooms                0
# bathrooms               0
# balcony                 0
# additional_room       126
# floor_info              0
# facing                 67
# property_age            1
# furnishing_details     72
# features               38
# nearby_location         0
# dtype: int64

# %% [markdown]
# ### 2. Independent Builder Floor Cleaning

# %%
df_builder_floor.columns
# Out:
# Index(['property_name', 'society', 'price', 'area', 'areawithtype',
#        'property_id', 'link', 'bedrooms', 'bathrooms', 'balcony',
#        'additional_room', 'floor_info', 'facing', 'property_age',
#        'furnishing_details', 'features', 'nearby_location'],
#       dtype='object')

# %%
df_builder_floor = df_builder_floor[['property_id','property_name', 'link', 'society', 'price', 'area',
       'areawithtype', 'bedrooms', 'bathrooms', 'balcony', 'additional_room',
       'floor_info', 'facing', 'property_age', 'nearby_location',
        'furnishing_details', 'features']]
df_builder_floor
# Out:
#      property_id                                      property_name  \
# 0      O85021804  4 BHK Independent Builder Floor in Sushant Lok...
# 1      V85303340  4 BHK Independent Builder Floor in Sector 102,...
# 2      O83672012  4 BHK Independent Builder Floor in A Block Sus...
# 3      K85623978  4 BHK Independent Builder Floor in DLF Phase 2...
# 4      E85624224  4 BHK Independent Builder Floor in DLF Phase 2...
# ...          ...                                                ...
# 1247   G78860067  4 BHK Independent Builder Floor in Sector 46, ...
# 1248   S85218742  4 BHK Independent Builder Floor in Sushant Lok...
# 1249   R85216914  4 BHK Independent Builder Floor in Sushant Lok...
# 1250   B84531164  4 BHK Independent Builder Floor in Sector 84, ...
# 1251   F84618392  4 BHK Independent Builder Floor in Sector 63A,...
#
#                                                    link  \
# 0     https://www.99acres.com/4-bhk-bedroom-independ...
# 1     https://www.99acres.com/4-bhk-bedroom-independ...
# 2     https://www.99acres.com/4-bhk-bedroom-independ...
# 3     https://www.99acres.com/4-bhk-bedroom-independ...
# 4     https://www.99acres.com/4-bhk-bedroom-independ...
# ...                                                 ...
# 1247  https://www.99acres.com/4-bhk-bedroom-independ...
# 1248  https://www.99acres.com/4-bhk-bedroom-independ...
# 1249  https://www.99acres.com/4-bhk-bedroom-independ...
# 1250  https://www.99acres.com/4-bhk-bedroom-independ...
# 1251  https://www.99acres.com/4-bhk-bedroom-independ...
#
#                                    society     price           area  \
# 0                  Brand New Builder Floor  ₹3.85 Cr  ₹14,259 /sqft
# 1                            BPTP Amstoria   ₹3.4 Cr  ₹17,000 /sqft
# 2     A Block Sushant Lok Phase 1, Gurgaon  ₹3.66 Cr  ₹13,811 /sqft
# 3                     DLF Phase 2, Gurgaon  ₹5.25 Cr  ₹19,444 /sqft
# 4                        PARK FACING FLOOR     ₹5 Cr  ₹12,500 /sqft
# ...                                    ...       ...            ...
# 1247                 Private Builder Floor     ₹3 Cr  ₹10,000 /sqft
# 1248          Sushant Lok 1 Builder Floors     ₹5 Cr  ₹22,727 /sqft
# 1249          Sushant Lok Phase 1, Gurgaon  ₹5.85 Cr  ₹20,892 /sqft
# 1250                      SS Linden Floors  ₹2.92 Cr  ₹10,428 /sqft
# 1251                     Anant Raj Estates   ₹3.8 Cr  ₹15,932 /sqft
#
#                                   areawithtype    bedrooms    bathrooms  \
# 0     2,700 sqft (251 sqm) Super Built-up Area  4 Bedrooms  4 Bathrooms
# 1             2,000 sqft (186 sqm) Carpet Area  4 Bedrooms  4 Bathrooms
# 2     2,650 sqft (246 sqm) Super Built-up Area  4 Bedrooms  4 Bathrooms
# 3             2,700 sqft (251 sqm) Carpet Area  4 Bedrooms  5 Bathrooms
# 4             4,000 sqft (372 sqm) Carpet Area  4 Bedrooms  5 Bathrooms
# ...                                        ...         ...          ...
# 1247  3,000 sqft (279 sqm) Super Built-up Area  4 Bedrooms  4 Bathrooms
# 1248          2,200 sqft (204 sqm) Carpet Area  4 Bedrooms  4 Bathrooms
# 1249          2,800 sqft (260 sqm) Carpet Area  4 Bedrooms  4 Bathrooms
# 1250        2,800 sqft (260 sqm) Built-up Area  4 Bedrooms  4 Bathrooms
# 1251  2,385 sqft (222 sqm) Super Built-up Area  4 Bedrooms  4 Bathrooms
#
#            balcony                            additional_room  \
# 0      2 Balconies                               Servant Room
# 1     3+ Balconies                                        NaN
# 2      2 Balconies                                 Study Room
# 3      3 Balconies  Pooja Room,Study Room,Servant Room,Others
# 4      2 Balconies  Pooja Room,Study Room,Servant Room,Others
# ...            ...                                        ...
# 1247   2 Balconies                               Servant Room
# 1248   3 Balconies                               Servant Room
# 1249  3+ Balconies                               Servant Room
# 1250   2 Balconies                               Servant Room
# 1251   3 Balconies                               Servant Room
#
#               floor_info      facing     property_age  \
# 0      2nd   of 4 Floors  North-East  0 to 1 Year Old
# 1      1st   of 4 Floors  North-East  1 to 5 Year Old
# 2      1st   of 4 Floors        East  1 to 5 Year Old
# 3      2nd   of 4 Floors        East  1 to 5 Year Old
# 4      3rd   of 4 Floors        East  0 to 1 Year Old
# ...                  ...         ...              ...
# 1247   1st   of 4 Floors  North-East  0 to 1 Year Old
# 1248  Ground of 4 Floors        West  0 to 1 Year Old
# 1249   2nd   of 4 Floors        East  0 to 1 Year Old
# 1250   2nd   of 4 Floors       North  0 to 1 Year Old
# 1251   4th   of 4 Floors  North-East  0 to 1 Year Old
#
#                                         nearby_location  \
# 0     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 1     ['Conscient One Mall', "Domino's Pizza", 'Daul...
# 2     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 3     ['Gurgaon Central Mall', 'Hanuman Mandir', 'PV...
# 4     ['Gurgaon Central Mall', 'PVR Cinames', 'Priva...
# ...                                                 ...
# 1247  ['Dr. Aruna Kalra', 'Raheja Mall', 'Delhi Publ...
# 1248  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1249  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1250  ['Agri Business Management Collage', 'Manesar ...
# 1251  ['De Adventure Park', 'Vatika Business Centre'...
#
#                                      furnishing_details  \
# 0     ['1 Water Purifier', '6 Fan', '1 Exhaust Fan',...
# 1     ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 2     ['3 Fan', '1 Fridge', '5 Geyser', '1 Stove', '...
# 3     ['1 Water Purifier', '12 Fan', '1 Exhaust Fan'...
# 4     ['11 Wardrobe', '13 Fan', '1 Exhaust Fan', '8 ...
# ...                                                 ...
# 1247  ['8 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1248  ['7 Fan', '1 Exhaust Fan', '5 Geyser', '1 Micr...
# 1249  ['4 Wardrobe', '7 Fan', '1 Exhaust Fan', '6 Ge...
# 1250  ['4 Wardrobe', '4 Geyser', '6 AC', '1 Modular ...
# 1251  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '5 Ge...
#
#                                                features
# 0     ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 1     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 2     ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 3     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 4     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# ...                                                 ...
# 1247  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1248  ['Security / Fire Alarm', 'Intercom Facility',...
# 1249  ['Security / Fire Alarm', 'Intercom Facility',...
# 1250  ['Water purifier', 'Centrally Air Conditioned'...
# 1251  ['Security / Fire Alarm', 'Private Garden / Te...
#
# [1252 rows x 17 columns]

# %%
missing_summary = (df_builder_floor
                    .isnull()
                    .sum()
                    .pipe(lambda d: d/(len(df_builder_floor)) * 100)
                    .reset_index()
                    .rename(columns={"index":"Feature/Column Name",0:"Missing Pct"})
                    .sort_values(by='Missing Pct', ascending=False)
)

# %%
missing_summary
# Out:
#    Feature/Column Name  Missing Pct
# 10     additional_room    10.063898
# 15  furnishing_details     5.750799
# 12              facing     5.351438
# 16            features     3.035144
# 13        property_age     0.079872
# 0          property_id     0.000000
# 1        property_name     0.000000
# 3              society     0.000000
# 2                 link     0.000000
# 8            bathrooms     0.000000
# 7             bedrooms     0.000000
# 6         areawithtype     0.000000
# 5                 area     0.000000
# 4                price     0.000000
# 9              balcony     0.000000
# 11          floor_info     0.000000
# 14     nearby_location     0.000000

# %% [markdown]
# ### 3. Individual Column Cleaning

# %% [markdown]
# #### 1. Property Name

# %%
df_builder_floor['property_name'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### 2. Society

# %%
df_builder_floor['society'].value_counts()
# Out:
# society
# Palam Vihar, Gurgaon                                 64
# Smart World Gems                                     46
# Ansal API Esencia                                    42
# Ansal API Versalia                                   38
# Block C, Sushant Lok Phase 1, Gurgaon                31
# Sector 23, Gurgaon                                   30
# Sector 57, Gurgaon                                   29
# DLF Phase 2, Gurgaon                                 28
# DLF Phase 1, Gurgaon                                 25
# Anant Raj Estates                                    24
# Private Builder Floor                                23
# M3M Soulitude                                        21
# Sushant Lok Phase 1, Gurgaon                         20
# DLF Garden City Floors                               20
# Malibu Town, Gurgaon                                 18
# Ansals Palam Vihar                                   17
# Sector 45, Gurgaon                                   16
# DLF Phase 1 Ultra Luxury Builder Floors              15
# South City 1, Gurgaon                                15
# Emaar Emerald Hills                                  14
# DLF Phase 4, Gurgaon                                 14
# South City 2, Gurgaon                                12
# Luxury Builder floor In South City 2                 12
# Super Luxury Two Side Open                            1
# Ireo City Plots                                       1
# Green Meadows                                         1
# A Block Sector 55                                     1
# avenue 49                                             1
# A Block Sushant Lok Phase - 3, Gurgaon                1
# S Block DLF Phase 3, Gurgaon                          1
# sector 49                                             1
# South City, Gurgaon                                   1
# Sector 10, Gurgaon                                    1
# Ansals Boom Plaza                                     1
# Sector 49, Gurgaon                                    1
# Block I South City 1, Gurgaon                         1
# Nirvana Cedar Crest                                   1
# Sector-35 Sohna, Gurgaon                              1
# vatika P block                                        1
# Block D sector 56, Gurgaon                            1
# Block E sector 56, Gurgaon                            1
# SS Almeria                                            1
# Block H South city 2, Gurgaon                         1
# TOP FLOOR 5BHK                                        1
# Dlf Phase 4 Brand New Builder Floor                   1
# Name: count, dtype: int64

# %%
df_builder_floor['society'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### 2. Price_in_Cr

# %%
df_builder_floor = df_builder_floor.rename(columns ={
    'price' : 'price_in_cr',
    'area'  :'price_per_sqft'
})

# %%
df_builder_floor['price_in_cr'].value_counts()
# Out:
# price_in_cr
# ₹3.5 Cr       37
# ₹3.25 Cr      31
# ₹3 Cr         31
# ₹4.25 Cr      27
# ₹4 Cr         27
# ₹3.3 Cr       26
# ₹2.9 Cr       24
# ₹4.5 Cr       22
# ₹4.1 Cr       22
# ₹2.7 Cr       22
# ₹3.4 Cr       21
# ₹2.6 Cr       20
# ₹2.65 Cr      20
# ₹3.75 Cr      20
# ₹3.2 Cr       19
# ₹2.85 Cr      19
# ₹3.1 Cr       18
# ₹3.8 Cr       17
# ₹3.15 Cr      17
# ₹6.5 Cr       16
# ₹2.95 Cr      16
# ₹2.5 Cr       16
# ₹2.8 Cr       16
# ₹2.75 Cr      15
# ₹3.9 Cr       15
# ₹2.3 Cr       14
# ₹1.65 Cr      13
# ₹3.6 Cr       12
# ₹5 Cr         12
# ₹5.5 Cr       12
# ₹3.7 Cr       11
# ₹2.45 Cr      11
# ₹6 Cr         11
# ₹5.25 Cr      11
# ₹3.65 Cr      11
# ₹1.62 Cr      10
# ₹3.85 Cr      10
# ₹2.55 Cr       9
# ₹2.4 Cr        9
# ₹2.99 Cr       9
# ₹3.35 Cr       9
# ₹2 Cr          9
# ₹4.2 Cr        9
# ₹3.95 Cr       9
# ₹6.25 Cr       8
# ₹2.2 Cr        8
# ₹4.75 Cr       8
# ₹3.05 Cr       8
# ₹1.35 Cr       8
# ₹4.4 Cr        8
# ₹1.7 Cr        7
# ₹4.35 Cr       7
# ₹1.64 Cr       7
# ₹2.25 Cr       7
# ₹3.45 Cr       7
# ₹1.75 Cr       6
# ₹5.9 Cr        6
# ₹8 Cr          6
# ₹1.6 Cr        6
# ₹4.65 Cr       6
# ₹5.75 Cr       6
# ₹5.8 Cr        6
# ₹5.85 Cr       6
# ₹3.49 Cr       5
# ₹2.15 Cr       5
# ₹2.35 Cr       5
# ₹4.15 Cr       5
# ₹6.1 Cr        5
# ₹6.75 Cr       5
# ₹1.95 Cr       5
# ₹6.3 Cr        5
# ₹4.85 Cr       5
#        '6 Cr', '5.5 Cr', '4 Cr', '3 Cr', '3.1 Cr', '3.95 Cr', '6.5 Cr',
#        '3.18 Cr', '4.15 Cr', '8 Cr', '4.25 Cr', '4.33 Cr', '8.5 Cr',
#        '2.54 Cr', '3.91 Cr', '6.1 Cr', '11.01 Cr', '3.99 Cr', '4.75 Cr',
#        '7.15 Cr', '3.2 Cr', '3.45 Cr', '3.9 Cr', '2.2 Cr', '2.96 Cr',
#        '3.89 Cr', '5.3 Cr', '3.24 Cr', '2.8 Cr', '3.65 Cr', '1.63 Cr',
#        '5.95 Cr', '6.25 Cr', '2.18 Cr', '8.9 Cr', '2.75 Cr', '3.44 Cr',
#        '3.33 Cr', '2.3 Cr', '3.3 Cr', '1.65 Cr', '4.7 Cr', '2.7 Cr',
#        '2.71 Cr', '2.85 Cr', '3.05 Cr', '1.7 Cr', '3.75 Cr', '1.62 Cr',
#        '6.19 Cr', '3.15 Cr', '2.6 Cr', '2.45 Cr', '2.99 Cr', '1.46 Cr',
#        '1.74 Cr', '6.3 Cr', '2.9 Cr', '3.5 Cr', '4.21 Cr', '5.75 Cr',
#        '11 Cr', '2.49 Cr', '13.5 Cr', '4.3 Cr', '5.85 Cr', '6.8 Cr',
#        '7.1 Cr', '3.25 Cr', '2.5 Cr', '1.45 Cr', '1.64 Cr', '7.25 Cr',
#        '1.6 Cr', '4.65 Cr', '1.32 Cr', '3.12 Cr', '6.45 Cr', '2.65 Cr',
#        '2.55 Cr', '2.95 Cr', '1.35 Cr', '13.95 Cr', '5.8 Cr', '4.2 Cr',
#        '1.55 Cr', '2.16 Cr', '7.3 Cr', '4.45 Cr', '7.49 Cr', '5.45 Cr',
#        '5.35 Cr', '12.85 Cr', '1.95 Cr', '1.59 Cr', '7 Cr', '3.6 Cr',
#        '6.9 Cr', '4.28 Cr', '2 Cr', '2.51 Cr', '1.1 Cr', '2.52 Cr',
#        '1.97 Cr', '6.75 Cr', '6.2 Cr', '4.85 Cr', '3.7 Cr', '1.56 Cr',
#        '6.49 Cr', '4.49 Cr', '3.58 Cr', '3.14 Cr', '2.69 Cr', '1.18 Cr',
#        '6.74 Cr', '1.4 Cr', '8.75 Cr', '2.35 Cr', '1.15 Cr', '3.49 Cr',
#        '1.68 Cr', '2.4 Cr', '2.09 Cr', '10.85 Cr', '1.93 Cr', '2.25 Cr',
#        '6.7 Cr', '1.58 Cr', '2.1 Cr', '4.8 Cr', '10.9 Cr', '5.29 Cr',
#        '4.9 Cr', '1.51 Cr', '4.11 Cr', '5.89 Cr', '3.55 Cr', '7.5 Cr',
#        '9 Cr', '3.02 Cr', '1.2 Cr', '1.71 Cr', '1.82 Cr', '1.48 Cr',
#        '12 Cr', '1.9 Cr', '6.15 Cr', '2.15 Cr', '1.75 Cr', '4.29 Cr',
#        '3.35 Cr', '10 Cr', '4.6 Cr', '1.41 Cr', '1.33 Cr', '74.85 Lac',
#        '6.6 Cr', '5.4 Cr', '5.34 Cr', '2.04 Cr', '4.62 Cr', '95 Lac',
#        '2.79 Cr', '5.55 Cr', '1.3 Cr', '11.5 Cr', '1.36 Cr', '1.98 Cr',
#        '4.55 Cr', '1.42 Cr', '1.34 Cr', '2.48 Cr', '3.13 Cr', '1.99 Cr',
#        '10.15 Cr', '9.35 Cr', '6.4 Cr', '7.45 Cr', '9.45 Cr', '1.23 Cr',
#        '3.87 Cr', '2.98 Cr', '4.95 Cr', '7.48 Cr', '4.99 Cr', '4.89 Cr',
#        '3.62 Cr', '2.92 Cr', '7.95 Cr', '5.65 Cr', '2.22 Cr', '2.61 Cr',
#        '5.1 Cr', '5.7 Cr', '1.85 Cr', '1.38 Cr', '2.74 Cr', '2.62 Cr',
#        '2.91 Cr', '2.53 Cr', '2.89 Cr', '1.29 Cr', '1.5 Cr', '2.77 Cr',
#        '3.48 Cr', '3.39 Cr', '6.98 Cr', '2.42 Cr', '1.25 Cr', '3.81 Cr',
#        '12.99 Cr', '1 Cr', '1.28 Cr', '4.19 Cr', '2.43 Cr', '2.78 Cr',
#        '1.39 Cr', '2.19 Cr', '3.88 Cr', '1.81 Cr', '1.92 Cr', '3.29 Cr',
#        '2.68 Cr', '2.05 Cr', '4.31 Cr', '17.75 Cr', '2.67 Cr', '2.66 Cr',
#        '2.29 Cr', '2.56 Cr', '2.64 Cr', '5.2 Cr', '2.21 Cr', '2.58 Cr',
#        '2.34 Cr', '4.05 Cr', '8.3 Cr', '3.69 Cr', '6.65 Cr', '2.11 Cr',
#        '6.39 Cr', '1.57 Cr', '3.98 Cr', '1.05 Cr', '1.22 Cr', '2.72 Cr',
#        '1.43 Cr', '75 Lac', '3.28 Cr', '1.73 Cr', '4.42 Cr', '3.23 Cr',
#        '2.33 Cr', '3.82 Cr', '80.5 Lac', '1.96 Cr', '3.72 Cr', '3.19 Cr',
#        '4.01 Cr', '5.02 Cr'], dtype=object)

# %%
column_cleaning = (df_builder_floor.assign
                   (
                       price_in_cr = lambda df_:df_['price_in_cr']
                                            .str.replace('₹','')
                   ))
column_cleaning['price_in_cr'].unique()
# Out:
# array(['3.85 Cr', '3.4 Cr', '3.66 Cr', '5.25 Cr', '5 Cr', '4.1 Cr',
#        '4.4 Cr', '5.9 Cr', '3.8 Cr', '4.35 Cr', '4.71 Cr', '4.5 Cr',
#        '6 Cr', '5.5 Cr', '4 Cr', '3 Cr', '3.1 Cr', '3.95 Cr', '6.5 Cr',
#        '3.18 Cr', '4.15 Cr', '8 Cr', '4.25 Cr', '4.33 Cr', '8.5 Cr',
#        '2.54 Cr', '3.91 Cr', '6.1 Cr', '11.01 Cr', '3.99 Cr', '4.75 Cr',
#        '7.15 Cr', '3.2 Cr', '3.45 Cr', '3.9 Cr', '2.2 Cr', '2.96 Cr',
#        '3.89 Cr', '5.3 Cr', '3.24 Cr', '2.8 Cr', '3.65 Cr', '1.63 Cr',
#        '5.95 Cr', '6.25 Cr', '2.18 Cr', '8.9 Cr', '2.75 Cr', '3.44 Cr',
#        '3.33 Cr', '2.3 Cr', '3.3 Cr', '1.65 Cr', '4.7 Cr', '2.7 Cr',
#        '2.71 Cr', '2.85 Cr', '3.05 Cr', '1.7 Cr', '3.75 Cr', '1.62 Cr',
#        '6.19 Cr', '3.15 Cr', '2.6 Cr', '2.45 Cr', '2.99 Cr', '1.46 Cr',
#        '1.74 Cr', '6.3 Cr', '2.9 Cr', '3.5 Cr', '4.21 Cr', '5.75 Cr',
#        '11 Cr', '2.49 Cr', '13.5 Cr', '4.3 Cr', '5.85 Cr', '6.8 Cr',
#        '7.1 Cr', '3.25 Cr', '2.5 Cr', '1.45 Cr', '1.64 Cr', '7.25 Cr',
#        '1.6 Cr', '4.65 Cr', '1.32 Cr', '3.12 Cr', '6.45 Cr', '2.65 Cr',
#        '2.55 Cr', '2.95 Cr', '1.35 Cr', '13.95 Cr', '5.8 Cr', '4.2 Cr',
#        '1.55 Cr', '2.16 Cr', '7.3 Cr', '4.45 Cr', '7.49 Cr', '5.45 Cr',
#        '5.35 Cr', '12.85 Cr', '1.95 Cr', '1.59 Cr', '7 Cr', '3.6 Cr',
#        '6.9 Cr', '4.28 Cr', '2 Cr', '2.51 Cr', '1.1 Cr', '2.52 Cr',
#        '1.97 Cr', '6.75 Cr', '6.2 Cr', '4.85 Cr', '3.7 Cr', '1.56 Cr',
#        '6.49 Cr', '4.49 Cr', '3.58 Cr', '3.14 Cr', '2.69 Cr', '1.18 Cr',
#        '6.74 Cr', '1.4 Cr', '8.75 Cr', '2.35 Cr', '1.15 Cr', '3.49 Cr',
#        '1.68 Cr', '2.4 Cr', '2.09 Cr', '10.85 Cr', '1.93 Cr', '2.25 Cr',
#        '6.7 Cr', '1.58 Cr', '2.1 Cr', '4.8 Cr', '10.9 Cr', '5.29 Cr',
#        '4.9 Cr', '1.51 Cr', '4.11 Cr', '5.89 Cr', '3.55 Cr', '7.5 Cr',
#        '9 Cr', '3.02 Cr', '1.2 Cr', '1.71 Cr', '1.82 Cr', '1.48 Cr',
#        '12 Cr', '1.9 Cr', '6.15 Cr', '2.15 Cr', '1.75 Cr', '4.29 Cr',
#        '3.35 Cr', '10 Cr', '4.6 Cr', '1.41 Cr', '1.33 Cr', '74.85 Lac',
#        '6.6 Cr', '5.4 Cr', '5.34 Cr', '2.04 Cr', '4.62 Cr', '95 Lac',
#        '2.79 Cr', '5.55 Cr', '1.3 Cr', '11.5 Cr', '1.36 Cr', '1.98 Cr',
#        '4.55 Cr', '1.42 Cr', '1.34 Cr', '2.48 Cr', '3.13 Cr', '1.99 Cr',
#        '10.15 Cr', '9.35 Cr', '6.4 Cr', '7.45 Cr', '9.45 Cr', '1.23 Cr',
#        '3.87 Cr', '2.98 Cr', '4.95 Cr', '7.48 Cr', '4.99 Cr', '4.89 Cr',
#        '3.62 Cr', '2.92 Cr', '7.95 Cr', '5.65 Cr', '2.22 Cr', '2.61 Cr',
#        '5.1 Cr', '5.7 Cr', '1.85 Cr', '1.38 Cr', '2.74 Cr', '2.62 Cr',
#        '2.91 Cr', '2.53 Cr', '2.89 Cr', '1.29 Cr', '1.5 Cr', '2.77 Cr',
#        '3.48 Cr', '3.39 Cr', '6.98 Cr', '2.42 Cr', '1.25 Cr', '3.81 Cr',
#        '12.99 Cr', '1 Cr', '1.28 Cr', '4.19 Cr', '2.43 Cr', '2.78 Cr',
#        '1.39 Cr', '2.19 Cr', '3.88 Cr', '1.81 Cr', '1.92 Cr', '3.29 Cr',
#        '2.68 Cr', '2.05 Cr', '4.31 Cr', '17.75 Cr', '2.67 Cr', '2.66 Cr',
#        '2.29 Cr', '2.56 Cr', '2.64 Cr', '5.2 Cr', '2.21 Cr', '2.58 Cr',
#        '2.34 Cr', '4.05 Cr', '8.3 Cr', '3.69 Cr', '6.65 Cr', '2.11 Cr',
#        '6.39 Cr', '1.57 Cr', '3.98 Cr', '1.05 Cr', '1.22 Cr', '2.72 Cr',
#        '1.43 Cr', '75 Lac', '3.28 Cr', '1.73 Cr', '4.42 Cr', '3.23 Cr',
#        '2.33 Cr', '3.82 Cr', '80.5 Lac', '1.96 Cr', '3.72 Cr', '3.19 Cr',
#        '4.01 Cr', '5.02 Cr'], dtype=object)

# %%
column_cleaning['price_in_cr'].value_counts()
# Out:
# price_in_cr
# 3.5 Cr       37
# 3.25 Cr      31
# 3 Cr         31
# 4.25 Cr      27
# 4 Cr         27
# 3.3 Cr       26
# 2.9 Cr       24
# 4.5 Cr       22
# 4.1 Cr       22
# 2.7 Cr       22
# 3.4 Cr       21
# 2.6 Cr       20
# 2.65 Cr      20
# 3.75 Cr      20
# 3.2 Cr       19
# 2.85 Cr      19
# 3.1 Cr       18
# 3.8 Cr       17
# 3.15 Cr      17
# 6.5 Cr       16
# 2.95 Cr      16
# 2.5 Cr       16
# 2.8 Cr       16
# 2.75 Cr      15
# 3.9 Cr       15
# 2.3 Cr       14
# 1.65 Cr      13
# 3.6 Cr       12
# 5 Cr         12
# 5.5 Cr       12
# 3.7 Cr       11
# 2.45 Cr      11
# 6 Cr         11
# 5.25 Cr      11
# 3.65 Cr      11
# 1.62 Cr      10
# 3.85 Cr      10
# 2.55 Cr       9
# 2.4 Cr        9
# 2.99 Cr       9
# 3.35 Cr       9
# 2 Cr          9
# 4.2 Cr        9
# 3.95 Cr       9
# 6.25 Cr       8
# 2.2 Cr        8
# 4.75 Cr       8
# 3.05 Cr       8
# 1.35 Cr       8
# 4.4 Cr        8
# 1.7 Cr        7
# 4.35 Cr       7
# 1.64 Cr       7
# 2.25 Cr       7
# 3.45 Cr       7
# 1.75 Cr       6
# 5.9 Cr        6
# 8 Cr          6
# 1.6 Cr        6
# 4.65 Cr       6
# 5.75 Cr       6
# 5.8 Cr        6
# 5.85 Cr       6
# 3.49 Cr       5
# 2.15 Cr       5
# 2.35 Cr       5
# 4.15 Cr       5
# 6.1 Cr        5
# 6.75 Cr       5
# 1.95 Cr       5
# 6.3 Cr        5
# 4.85 Cr       5
# 4.7 Cr        4
# 4.95 Cr       4
# 1.3 Cr        4
# 1.99 Cr       4
# 1.63 Cr       4
# 5.95 Cr       4
# 1.9 Cr        4
# 3.55 Cr       4
# 1.58 Cr       4
# 1.4 Cr        4
# 6.2 Cr        4
# 4.8 Cr        4
# 2.05 Cr       4
# 5.45 Cr       4
# 7 Cr          4
# 1.59 Cr       4
# 1.55 Cr       4
# 4.45 Cr       4
# 2.68 Cr       3
# 2.56 Cr       3
# 2.51 Cr       3
# 1.56 Cr       3
# 4.49 Cr       3
# 2.66 Cr       3
# 2.62 Cr       3
# 2.96 Cr       3
# 5.3 Cr        3
# 5.1 Cr        3
# 2.61 Cr       3
# 7.5 Cr        3
# 1.33 Cr       3
# 4.55 Cr       3
# 1.68 Cr       3
# 1.32 Cr       3
# 7.25 Cr       3
# 1.45 Cr       3
# 6.8 Cr        3
# 4.3 Cr        3
# 4.21 Cr       3
# 2.69 Cr       3
# 1.18 Cr       3
# 1.5 Cr        3
# 5.65 Cr       3
# 4.9 Cr        2
# 1.15 Cr       2
# 1.71 Cr       2
# 2.49 Cr       2
# 13.5 Cr       2
# 1.46 Cr       2
# 6.15 Cr       2
# 1.2 Cr        2
# 2.79 Cr       2
# 9 Cr          2
# 4.11 Cr       2
# 4.6 Cr        2
# 12 Cr         2
# 2.54 Cr       2
# 4.05 Cr       2
# 5.2 Cr        2
# 7.3 Cr        2
# 8.5 Cr        2
# 3.99 Cr       2
# 2.52 Cr       2
# 5.35 Cr       2
# 2.16 Cr       2
# 1.85 Cr       2
# 3.62 Cr       2
# 2.92 Cr       2
# 2.22 Cr       2
# 2.98 Cr       2
# 2.71 Cr       2
# 7.45 Cr       2
# 6.4 Cr        2
# 6.19 Cr       2
# 8.75 Cr       2
# 2.89 Cr       2
# 1.29 Cr       2
# 3.39 Cr       2
# 2.18 Cr       2
# 12.85 Cr      1
# 6.9 Cr        1
# 6.49 Cr       1
# 1.97 Cr       1
# 4.28 Cr       1
# 1.1 Cr        1
# 1.57 Cr       1
# 7.49 Cr       1
# 2.11 Cr       1
# 6.39 Cr       1
# 17.75 Cr      1
# 2.64 Cr       1
# 2.67 Cr       1
# 2.29 Cr       1
# 2.21 Cr       1
# 4.19 Cr       1
# 2.43 Cr       1
# 1 Cr          1
# 2.78 Cr       1
# 1.39 Cr       1
# 3.88 Cr       1
# 2.19 Cr       1
# 1.81 Cr       1
# 1.92 Cr       1
# 3.29 Cr       1
# 4.31 Cr       1
# 3.66 Cr       1
# 3.18 Cr       1
# 4.71 Cr       1
# 1.28 Cr       1
# 11.01 Cr      1
# 7.15 Cr       1
# 4.33 Cr       1
# 3.91 Cr       1
# 3.98 Cr       1
# 2.58 Cr       1
# 2.34 Cr       1
# 8.3 Cr        1
# 3.69 Cr       1
# 6.65 Cr       1
# 13.95 Cr      1
# 1.82 Cr       1
# 1.51 Cr       1
# 5.29 Cr       1
# 10.9 Cr       1
# 2.1 Cr        1
# 1.93 Cr       1
# 6.7 Cr        1
# 10.85 Cr      1
# 2.09 Cr       1
# 6.45 Cr       1
# 3.12 Cr       1
# 7.1 Cr        1
# 1.74 Cr       1
# 3.58 Cr       1
# 11 Cr         1
# 6.74 Cr       1
# 3.14 Cr       1
# 2.48 Cr       1
# 1.34 Cr       1
# 1.42 Cr       1
# 1.98 Cr       1
# 11.5 Cr       1
# 1.36 Cr       1
# 5.55 Cr       1
# 95 Lac        1
# 6.6 Cr        1
# 4.62 Cr       1
# 2.04 Cr       1
# 5.34 Cr       1
# 74.85 Lac     1
# 5.4 Cr        1
# 10 Cr         1
# 1.41 Cr       1
# 3.02 Cr       1
# 5.89 Cr       1
# 1.48 Cr       1
# 4.29 Cr       1
# 3.44 Cr       1
# 3.33 Cr       1
# 3.24 Cr       1
# 3.89 Cr       1
# 4.99 Cr       1
# 4.89 Cr       1
# 3.87 Cr       1
# 8.9 Cr        1
# 9.35 Cr       1
# 10.15 Cr      1
# 9.45 Cr       1
# 3.13 Cr       1
# 1.38 Cr       1
# 5.7 Cr        1
# 7.95 Cr       1
# 1.23 Cr       1
# 7.48 Cr       1
# 2.53 Cr       1
# 2.74 Cr       1
# 2.91 Cr       1
# 2.77 Cr       1
# 3.48 Cr       1
# 6.98 Cr       1
# 2.42 Cr       1
# 1.25 Cr       1
# 3.81 Cr       1
# 12.99 Cr      1
# 1.05 Cr       1
# 1.22 Cr       1
# 2.72 Cr       1
# 1.43 Cr       1
# 75 Lac        1
# 3.28 Cr       1
# 1.73 Cr       1
# 4.42 Cr       1
# 3.23 Cr       1
# 2.33 Cr       1
# 3.82 Cr       1
# 80.5 Lac      1
# 1.96 Cr       1
# 3.72 Cr       1
# 3.19 Cr       1
# 4.01 Cr       1
# 5.02 Cr       1
# Name: count, dtype: int64

# %%
df_builder_floor[df_builder_floor['price_in_cr']=='Price on Request']
# Out:
# Empty DataFrame
# Columns: [property_id, property_name, link, society, price_in_cr, price_per_sqft, areawithtype, bedrooms, bathrooms, balcony, additional_room, floor_info, facing, property_age, nearby_location, furnishing_details, features]
# Index: []

# %%
column_cleaning = (

        df_builder_floor
        .assign(
            
        price_in_cr = lambda df_:df_['price_in_cr']
                .str
                .replace('₹','')
                )

        .assign(
                price_in_cr = lambda df_: round(pd.to_numeric(df_['price_in_cr']
                .apply(lambda value: (float(str(value)
                .replace('Cr', '')
                .strip()) if 'Cr' in str(value)
                else float(str(value)
                .replace('Lac', '')
                .strip()) / 100
                ) if value not in ['Price on Request', None, np.nan] else np.nan
                        )
            ),2)
            )
)     

column_cleaning
# Out:
#      property_id                                      property_name  \
# 0      O85021804  4 BHK Independent Builder Floor in Sushant Lok...
# 1      V85303340  4 BHK Independent Builder Floor in Sector 102,...
# 2      O83672012  4 BHK Independent Builder Floor in A Block Sus...
# 3      K85623978  4 BHK Independent Builder Floor in DLF Phase 2...
# 4      E85624224  4 BHK Independent Builder Floor in DLF Phase 2...
# ...          ...                                                ...
# 1247   G78860067  4 BHK Independent Builder Floor in Sector 46, ...
# 1248   S85218742  4 BHK Independent Builder Floor in Sushant Lok...
# 1249   R85216914  4 BHK Independent Builder Floor in Sushant Lok...
# 1250   B84531164  4 BHK Independent Builder Floor in Sector 84, ...
# 1      1st   of 4 Floors  North-East  1 to 5 Year Old
# 2      1st   of 4 Floors        East  1 to 5 Year Old
# 3      2nd   of 4 Floors        East  1 to 5 Year Old
# 4      3rd   of 4 Floors        East  0 to 1 Year Old
# ...                  ...         ...              ...
# 1247   1st   of 4 Floors  North-East  0 to 1 Year Old
# 1248  Ground of 4 Floors        West  0 to 1 Year Old
# 1249   2nd   of 4 Floors        East  0 to 1 Year Old
# 1250   2nd   of 4 Floors       North  0 to 1 Year Old
# 1251   4th   of 4 Floors  North-East  0 to 1 Year Old
#
#                                         nearby_location  \
# 0     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 1     ['Conscient One Mall', "Domino's Pizza", 'Daul...
# 2     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 3     ['Gurgaon Central Mall', 'Hanuman Mandir', 'PV...
# 4     ['Gurgaon Central Mall', 'PVR Cinames', 'Priva...
# ...                                                 ...
# 1247  ['Dr. Aruna Kalra', 'Raheja Mall', 'Delhi Publ...
# 1248  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1249  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1250  ['Agri Business Management Collage', 'Manesar ...
# 1251  ['De Adventure Park', 'Vatika Business Centre'...
#
#                                      furnishing_details  \
# 0     ['1 Water Purifier', '6 Fan', '1 Exhaust Fan',...
# 1     ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 2     ['3 Fan', '1 Fridge', '5 Geyser', '1 Stove', '...
# 3     ['1 Water Purifier', '12 Fan', '1 Exhaust Fan'...
# 4     ['11 Wardrobe', '13 Fan', '1 Exhaust Fan', '8 ...
# ...                                                 ...
# 1247  ['8 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1248  ['7 Fan', '1 Exhaust Fan', '5 Geyser', '1 Micr...
# 1249  ['4 Wardrobe', '7 Fan', '1 Exhaust Fan', '6 Ge...
# 1250  ['4 Wardrobe', '4 Geyser', '6 AC', '1 Modular ...
# 1251  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '5 Ge...
#
#                                                features
# 0     ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 1     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 2     ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 3     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 4     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# ...                                                 ...
# 1247  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1248  ['Security / Fire Alarm', 'Intercom Facility',...
# 1249  ['Security / Fire Alarm', 'Intercom Facility',...
# 1250  ['Water purifier', 'Centrally Air Conditioned'...
# 1251  ['Security / Fire Alarm', 'Private Garden / Te...
#
# [1252 rows x 17 columns]

# %%
column_cleaning['price_in_cr'].value_counts()
# Out:
# price_in_cr
# 3.50     37
# 3.00     31
# 3.25     31
# 4.00     27
# 4.25     27
# 3.30     26
# 2.90     24
# 6.90      1
# 12.85     1
# 6.65      1
# 1.57      1
# 6.39      1
# 2.11      1
# 3.98      1
# 7.49      1
# 2.34      1
# 8.30      1
# 3.69      1
# 0.95      1
# 4.62      1
# 2.04      1
# 5.34      1
# 5.40      1
# 6.60      1
# 1.41      1
# 10.00     1
# 7.10      1
# 4.29      1
# 13.95     1
# 6.45      1
# 3.12      1
# 1.48      1
# 2.48      1
# 5.55      1
# 3.24      1
# 3.89      1
# 9.45      1
# 9.35      1
# 3.13      1
# 10.15     1
# 1.34      1
# 8.90      1
# 3.87      1
# 1.23      1
# 3.44      1
# 3.33      1
# 1.98      1
# 1.42      1
# 11.50     1
# 1.36      1
# 7.95      1
# 7.48      1
# 4.99      1
# 4.89      1
# 2.74      1
# 1.38      1
# 2.53      1
# 5.70      1
# 2.91      1
# 2.77      1
# 3.48      1
# 6.98      1
# 2.42      1
# 1.25      1
# 3.81      1
# 12.99     1
# 1.05      1
# 1.22      1
# 2.72      1
# 1.43      1
# 3.28      1
# 1.73      1
# 4.42      1
# 3.23      1
# 2.33      1
# 3.82      1
# 0.80      1
# 1.96      1
# 3.72      1
# 3.19      1
# 4.01      1
# 5.02      1
# Name: count, dtype: int64

# %%
column_cleaning['price_in_cr'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### 3. Price_Per_Sqft

# %%
column_cleaning['price_per_sqft']
# Out:
# 0       ₹14,259 /sqft
# 1       ₹17,000 /sqft
# 2       ₹13,811 /sqft
# 3       ₹19,444 /sqft
# 4       ₹12,500 /sqft
#             ...
# 1247    ₹10,000 /sqft
# 1248    ₹22,727 /sqft
# 1249    ₹20,892 /sqft
# 1250    ₹10,428 /sqft
# 1251    ₹15,932 /sqft
# Name: price_per_sqft, Length: 1252, dtype: object

# %%
column_cleaning = (df_builder_floor
                .assign(
                price_per_sqft = lambda df_:df_['price_per_sqft']
                    .str
                    .split("₹")
                    .str
                    .get(1)
                    .str
                    .replace("/sqft","")
                    .str
                    .replace(",","")
                    .str 
                    .strip()))

# %%
column_cleaning['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# 13888    13
# 11111    13
# 13333    13
# 12222    11
# 10000    11
#          ..
# 17473     1
# 19493     1
# 13451     1
# 10689     1
# 14338     1
# Name: count, Length: 874, dtype: int64

# %%
column_cleaning = (
    
    df_builder_floor
    
        .assign(
            price_in_cr = lambda df_: df_['price_in_cr']
                                        .str
                                        .replace('₹', '', regex=False)
                )

      
        .assign(
            price_in_cr=lambda df_: round(pd.to_numeric(df_['price_in_cr']
                                        .apply(lambda value: (float(str(value)
                                        .replace('Cr', '')
                                        .strip())
                                        if 'Cr' in str(value)
                                        else float(str(value)
                                        .replace('Lac', '')
                                        .strip()) / 100)
                                        if value not in ['Price on Request', None, np.nan] 
                                        else np.nan)),2)
                )

     
        .assign(
            price_per_sqft=lambda df_: pd.to_numeric(df_['price_per_sqft']
                                        .astype(str)
                                        .str
                                        .split("₹")
                                        .str
                                        .get(1)
                                        .str
                                        .replace("/sqft", "", regex=False)
                                        .str
# 0      2 Balconies                               Servant Room
# 1     3+ Balconies                                        NaN
# 2      2 Balconies                                 Study Room
# 3      3 Balconies  Pooja Room,Study Room,Servant Room,Others
# 4      2 Balconies  Pooja Room,Study Room,Servant Room,Others
# ...            ...                                        ...
# 1247   2 Balconies                               Servant Room
# 1248   3 Balconies                               Servant Room
# 1249  3+ Balconies                               Servant Room
# 1250   2 Balconies                               Servant Room
# 1251   3 Balconies                               Servant Room
#
#               floor_info      facing     property_age  \
# 0      2nd   of 4 Floors  North-East  0 to 1 Year Old
# 1      1st   of 4 Floors  North-East  1 to 5 Year Old
# 2      1st   of 4 Floors        East  1 to 5 Year Old
# 3      2nd   of 4 Floors        East  1 to 5 Year Old
# 4      3rd   of 4 Floors        East  0 to 1 Year Old
# ...                  ...         ...              ...
# 1247   1st   of 4 Floors  North-East  0 to 1 Year Old
# 1248  Ground of 4 Floors        West  0 to 1 Year Old
# 1249   2nd   of 4 Floors        East  0 to 1 Year Old
# 1250   2nd   of 4 Floors       North  0 to 1 Year Old
# 1251   4th   of 4 Floors  North-East  0 to 1 Year Old
#
#                                         nearby_location  \
# 0     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 1     ['Conscient One Mall', "Domino's Pizza", 'Daul...
# 2     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 3     ['Gurgaon Central Mall', 'Hanuman Mandir', 'PV...
# 4     ['Gurgaon Central Mall', 'PVR Cinames', 'Priva...
# ...                                                 ...
# 1247  ['Dr. Aruna Kalra', 'Raheja Mall', 'Delhi Publ...
# 1248  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1249  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1250  ['Agri Business Management Collage', 'Manesar ...
# 1251  ['De Adventure Park', 'Vatika Business Centre'...
#
#                                      furnishing_details  \
# 0     ['1 Water Purifier', '6 Fan', '1 Exhaust Fan',...
# 1     ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 2     ['3 Fan', '1 Fridge', '5 Geyser', '1 Stove', '...
# 3     ['1 Water Purifier', '12 Fan', '1 Exhaust Fan'...
# 4     ['11 Wardrobe', '13 Fan', '1 Exhaust Fan', '8 ...
# ...                                                 ...
# 1247  ['8 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1248  ['7 Fan', '1 Exhaust Fan', '5 Geyser', '1 Micr...
# 1249  ['4 Wardrobe', '7 Fan', '1 Exhaust Fan', '6 Ge...
# 1250  ['4 Wardrobe', '4 Geyser', '6 AC', '1 Modular ...
# 1251  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '5 Ge...
#
#                                                features
# 0     ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 1     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 2     ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 3     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 4     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# ...                                                 ...
# 1247  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1248  ['Security / Fire Alarm', 'Intercom Facility',...
# 1249  ['Security / Fire Alarm', 'Intercom Facility',...
# 1250  ['Water purifier', 'Centrally Air Conditioned'...
# 1251  ['Security / Fire Alarm', 'Private Garden / Te...
#
# [1252 rows x 17 columns]

# %% [markdown]
# #### 4. Bedroom

# %%
column_cleaning['bedrooms'].unique()
# Out:
# array(['4 Bedrooms', '3 Bedrooms', '5 Bedrooms', '2 Bedrooms',
#        '9 Bedrooms'], dtype=object)

# %%
(column_cleaning['bedrooms']
                .str
                .split(" ")
                .str
                .get(0))
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 1247    4
# 1248    4
# 1249    4
# 1250    4
# 1251    4
# Name: bedrooms, Length: 1252, dtype: object

# %%
column_cleaning = (
    
    df_builder_floor
    
        .assign(
            price_in_cr = lambda df_: df_['price_in_cr']
                                        .str
                                        .replace('₹', '', regex=False)
                )

      
        .assign(
            price_in_cr = lambda df_: round(pd.to_numeric(df_['price_in_cr']
                                        .apply(lambda value: (float(str(value)
                                        .replace('Cr', '')
                                        .strip())
                                        if 'Cr' in str(value)
                                        else float(str(value)
                                        .replace('Lac', '')
                                        .strip()) / 100)
                                        if value not in ['Price on Request', None, np.nan] 
                                        else np.nan)),2)
                )

     
        .assign(
            price_per_sqft = lambda df_: pd.to_numeric(df_['price_per_sqft']
                                        .astype(str)
                                        .str
                                        .split("₹")
                                        .str
                                        .get(1)
                                        .str
                                        .replace("/sqft", "", regex=False)
                                        .str
                                        .replace(",", "", regex=False)
                                        .str
                                        .strip())
                
            ,
            bedrooms = lambda df_:df_['bedrooms']
                                          .str
                                        .split(" ")
                                        .str
                                        .get(0)
                )

)

column_cleaning
# Out:
#      property_id                                      property_name  \
# 0      O85021804  4 BHK Independent Builder Floor in Sushant Lok...
# 1      V85303340  4 BHK Independent Builder Floor in Sector 102,...
# 2      O83672012  4 BHK Independent Builder Floor in A Block Sus...
# 3      K85623978  4 BHK Independent Builder Floor in DLF Phase 2...
# 4      E85624224  4 BHK Independent Builder Floor in DLF Phase 2...
# ...          ...                                                ...
# 1247   G78860067  4 BHK Independent Builder Floor in Sector 46, ...
# 1248   S85218742  4 BHK Independent Builder Floor in Sushant Lok...
# 1249   R85216914  4 BHK Independent Builder Floor in Sushant Lok...
# 1250   B84531164  4 BHK Independent Builder Floor in Sector 84, ...
# 1251   F84618392  4 BHK Independent Builder Floor in Sector 63A,...
#
#                                                    link  \
# 0     https://www.99acres.com/4-bhk-bedroom-independ...
# 1     https://www.99acres.com/4-bhk-bedroom-independ...
# 2     https://www.99acres.com/4-bhk-bedroom-independ...
# 3     https://www.99acres.com/4-bhk-bedroom-independ...
# 4     https://www.99acres.com/4-bhk-bedroom-independ...
# ...                                                 ...
# 1247  https://www.99acres.com/4-bhk-bedroom-independ...
# 1248  https://www.99acres.com/4-bhk-bedroom-independ...
# 1249  https://www.99acres.com/4-bhk-bedroom-independ...
# 1250  https://www.99acres.com/4-bhk-bedroom-independ...
# 1251  https://www.99acres.com/4-bhk-bedroom-independ...
#
#                                    society  price_in_cr  price_per_sqft  \
# 0                  Brand New Builder Floor         3.85           14259
# 1                            BPTP Amstoria         3.40           17000
# 2     A Block Sushant Lok Phase 1, Gurgaon         3.66           13811
# 3                     DLF Phase 2, Gurgaon         5.25           19444
# 4                        PARK FACING FLOOR         5.00           12500
# ...                                    ...          ...             ...
# 1247                 Private Builder Floor         3.00           10000
# 1248          Sushant Lok 1 Builder Floors         5.00           22727
# 1249          Sushant Lok Phase 1, Gurgaon         5.85           20892
# 1250                      SS Linden Floors         2.92           10428
# 1251                     Anant Raj Estates         3.80           15932
#
#                                   areawithtype bedrooms    bathrooms  \
# 0     2,700 sqft (251 sqm) Super Built-up Area        4  4 Bathrooms
# 1             2,000 sqft (186 sqm) Carpet Area        4  4 Bathrooms
# 2     2,650 sqft (246 sqm) Super Built-up Area        4  4 Bathrooms
# 3             2,700 sqft (251 sqm) Carpet Area        4  5 Bathrooms
# 4             4,000 sqft (372 sqm) Carpet Area        4  5 Bathrooms
# ...                                        ...      ...          ...
# 1247  3,000 sqft (279 sqm) Super Built-up Area        4  4 Bathrooms
# 1248          2,200 sqft (204 sqm) Carpet Area        4  4 Bathrooms
# 1249          2,800 sqft (260 sqm) Carpet Area        4  4 Bathrooms
# 1250        2,800 sqft (260 sqm) Built-up Area        4  4 Bathrooms
# 1251  2,385 sqft (222 sqm) Super Built-up Area        4  4 Bathrooms
#
#            balcony                            additional_room  \
# 0      2 Balconies                               Servant Room
# 1     3+ Balconies                                        NaN
# 2      2 Balconies                                 Study Room
# 3      3 Balconies  Pooja Room,Study Room,Servant Room,Others
# 4      2 Balconies  Pooja Room,Study Room,Servant Room,Others
# ...            ...                                        ...
# 1247   2 Balconies                               Servant Room
# 1248   3 Balconies                               Servant Room
# 1249  3+ Balconies                               Servant Room
# 1250   2 Balconies                               Servant Room
# 1251   3 Balconies                               Servant Room
#
#               floor_info      facing     property_age  \
# 0      2nd   of 4 Floors  North-East  0 to 1 Year Old
# 1      1st   of 4 Floors  North-East  1 to 5 Year Old
# 2      1st   of 4 Floors        East  1 to 5 Year Old
# 3      2nd   of 4 Floors        East  1 to 5 Year Old
# 4      3rd   of 4 Floors        East  0 to 1 Year Old
# ...                  ...         ...              ...
# 1247   1st   of 4 Floors  North-East  0 to 1 Year Old
# 1248  Ground of 4 Floors        West  0 to 1 Year Old
# 1249   2nd   of 4 Floors        East  0 to 1 Year Old
# 1250   2nd   of 4 Floors       North  0 to 1 Year Old
# 1251   4th   of 4 Floors  North-East  0 to 1 Year Old
#
#                                         nearby_location  \
# 0     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 1     ['Conscient One Mall', "Domino's Pizza", 'Daul...
# 2     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 3     ['Gurgaon Central Mall', 'Hanuman Mandir', 'PV...
# 4     ['Gurgaon Central Mall', 'PVR Cinames', 'Priva...
# ...                                                 ...
# 1247  ['Dr. Aruna Kalra', 'Raheja Mall', 'Delhi Publ...
# 1248  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1249  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1250  ['Agri Business Management Collage', 'Manesar ...
# 1251  ['De Adventure Park', 'Vatika Business Centre'...
#
#                                      furnishing_details  \
# 0     ['1 Water Purifier', '6 Fan', '1 Exhaust Fan',...
# 1     ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 2     ['3 Fan', '1 Fridge', '5 Geyser', '1 Stove', '...
# 3     ['1 Water Purifier', '12 Fan', '1 Exhaust Fan'...
# 4     ['11 Wardrobe', '13 Fan', '1 Exhaust Fan', '8 ...
# ...                                                 ...
# 1247  ['8 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1248  ['7 Fan', '1 Exhaust Fan', '5 Geyser', '1 Micr...
# 1249  ['4 Wardrobe', '7 Fan', '1 Exhaust Fan', '6 Ge...
# 1250  ['4 Wardrobe', '4 Geyser', '6 AC', '1 Modular ...
# 1251  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '5 Ge...
#
#                                                features
# 0     ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 1     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 2     ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 3     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 4     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# ...                                                 ...
# 1247  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1248  ['Security / Fire Alarm', 'Intercom Facility',...
# 1249  ['Security / Fire Alarm', 'Intercom Facility',...
# 1250  ['Water purifier', 'Centrally Air Conditioned'...
# 1251  ['Security / Fire Alarm', 'Private Garden / Te...
#
# [1252 rows x 17 columns]

# %%
column_cleaning['bedrooms'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### 5. Bathroom

# %%
column_cleaning['bathrooms'].unique()
# Out:
# array(['4 Bathrooms', '5 Bathrooms', '3 Bathrooms', '2 Bathrooms',
#        '6 Bathrooms', '9 Bathrooms', '7 Bathrooms'], dtype=object)

# %%
(column_cleaning['bathrooms']
            .str
            .split(" ")
            .str
            .get(0)
)
# Out:
# 0       4
# 1       4
# 2       4
# 3       5
# 4       5
#        ..
# 1247    4
# 1248    4
# 1249    4
# 1250    4
# 1251    4
# Name: bathrooms, Length: 1252, dtype: object

# %%
column_cleaning = (
    
    df_builder_floor
    
        .assign(
            price_in_cr = lambda df_: df_['price_in_cr']
                                        .str
                                        .replace('₹', '', regex=False)
                )

      
        .assign(
            price_in_cr = lambda df_: round(pd.to_numeric(df_['price_in_cr']
                                        .apply(lambda value: (float(str(value)
                                        .replace('Cr', '')
                                        .strip())
                                        if 'Cr' in str(value)
                                        else float(str(value)
                                        .replace('Lac', '')
                                        .strip()) / 100)
                                        if value not in ['Price on Request', None, np.nan] 
                                        else np.nan)),2)
                )

     
        .assign(
            price_per_sqft = lambda df_: pd.to_numeric(df_['price_per_sqft']
                                        .astype(str)
                                        .str
                                        .split("₹")
                                        .str
                                        .get(1)
                                        .str
                                        .replace("/sqft", "", regex=False)
                                        .str
                                        .replace(",", "", regex=False)
                                        .str
                                        .strip())
                
            ,
            bedrooms = lambda df_:df_['bedrooms']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
            ,
            bathrooms = lambda df_:df_['bathrooms']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
                )
)

column_cleaning
# Out:
#      property_id                                      property_name  \
# 0      O85021804  4 BHK Independent Builder Floor in Sushant Lok...
# 1      V85303340  4 BHK Independent Builder Floor in Sector 102,...
# 2      O83672012  4 BHK Independent Builder Floor in A Block Sus...
# 3      K85623978  4 BHK Independent Builder Floor in DLF Phase 2...
# 4      E85624224  4 BHK Independent Builder Floor in DLF Phase 2...
# ...          ...                                                ...
# 1247   G78860067  4 BHK Independent Builder Floor in Sector 46, ...
# 1248   S85218742  4 BHK Independent Builder Floor in Sushant Lok...
# 1249   R85216914  4 BHK Independent Builder Floor in Sushant Lok...
# 1250   B84531164  4 BHK Independent Builder Floor in Sector 84, ...
# 1251   F84618392  4 BHK Independent Builder Floor in Sector 63A,...
#
#                                                    link  \
# 0     https://www.99acres.com/4-bhk-bedroom-independ...
# 1     https://www.99acres.com/4-bhk-bedroom-independ...
# 2     https://www.99acres.com/4-bhk-bedroom-independ...
# 3     https://www.99acres.com/4-bhk-bedroom-independ...
# 4     https://www.99acres.com/4-bhk-bedroom-independ...
# ...                                                 ...
# 1247  https://www.99acres.com/4-bhk-bedroom-independ...
# 1248  https://www.99acres.com/4-bhk-bedroom-independ...
# 1249  https://www.99acres.com/4-bhk-bedroom-independ...
# 1250  https://www.99acres.com/4-bhk-bedroom-independ...
# 1251  https://www.99acres.com/4-bhk-bedroom-independ...
#
#                                    society  price_in_cr  price_per_sqft  \
# 0                  Brand New Builder Floor         3.85           14259
# 1                            BPTP Amstoria         3.40           17000
# 2     A Block Sushant Lok Phase 1, Gurgaon         3.66           13811
# 3                     DLF Phase 2, Gurgaon         5.25           19444
# 4                        PARK FACING FLOOR         5.00           12500
# ...                                    ...          ...             ...
# 1247                 Private Builder Floor         3.00           10000
# 1248          Sushant Lok 1 Builder Floors         5.00           22727
# 1249          Sushant Lok Phase 1, Gurgaon         5.85           20892
# 1250                      SS Linden Floors         2.92           10428
# 1251                     Anant Raj Estates         3.80           15932
#
#                                   areawithtype bedrooms bathrooms  \
# 0     2,700 sqft (251 sqm) Super Built-up Area        4         4
# 1             2,000 sqft (186 sqm) Carpet Area        4         4
# 2     2,650 sqft (246 sqm) Super Built-up Area        4         4
# 3             2,700 sqft (251 sqm) Carpet Area        4         5
# 4             4,000 sqft (372 sqm) Carpet Area        4         5
# ...                                        ...      ...       ...
# 1247  3,000 sqft (279 sqm) Super Built-up Area        4         4
# 1248          2,200 sqft (204 sqm) Carpet Area        4         4
# 1249          2,800 sqft (260 sqm) Carpet Area        4         4
# 1250        2,800 sqft (260 sqm) Built-up Area        4         4
# 1251  2,385 sqft (222 sqm) Super Built-up Area        4         4
#
#            balcony                            additional_room  \
# 0      2 Balconies                               Servant Room
# 1     3+ Balconies                                        NaN
# 2      2 Balconies                                 Study Room
# 3      3 Balconies  Pooja Room,Study Room,Servant Room,Others
# 4      2 Balconies  Pooja Room,Study Room,Servant Room,Others
# ...            ...                                        ...
# 1247   2 Balconies                               Servant Room
# 1248   3 Balconies                               Servant Room
# 1249  3+ Balconies                               Servant Room
# 1250   2 Balconies                               Servant Room
# 1251   3 Balconies                               Servant Room
#
#               floor_info      facing     property_age  \
# 0      2nd   of 4 Floors  North-East  0 to 1 Year Old
# 1      1st   of 4 Floors  North-East  1 to 5 Year Old
# 2      1st   of 4 Floors        East  1 to 5 Year Old
# 3      2nd   of 4 Floors        East  1 to 5 Year Old
# 4      3rd   of 4 Floors        East  0 to 1 Year Old
# ...                  ...         ...              ...
# 1247   1st   of 4 Floors  North-East  0 to 1 Year Old
# 1248  Ground of 4 Floors        West  0 to 1 Year Old
# 1249   2nd   of 4 Floors        East  0 to 1 Year Old
# 1250   2nd   of 4 Floors       North  0 to 1 Year Old
# 1251   4th   of 4 Floors  North-East  0 to 1 Year Old
#
#                                         nearby_location  \
# 0     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 1     ['Conscient One Mall', "Domino's Pizza", 'Daul...
# 2     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 3     ['Gurgaon Central Mall', 'Hanuman Mandir', 'PV...
# 4     ['Gurgaon Central Mall', 'PVR Cinames', 'Priva...
# ...                                                 ...
# 1247  ['Dr. Aruna Kalra', 'Raheja Mall', 'Delhi Publ...
# 1248  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1249  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1250  ['Agri Business Management Collage', 'Manesar ...
# 1251  ['De Adventure Park', 'Vatika Business Centre'...
#
#                                      furnishing_details  \
# 0     ['1 Water Purifier', '6 Fan', '1 Exhaust Fan',...
# 1     ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 2     ['3 Fan', '1 Fridge', '5 Geyser', '1 Stove', '...
# 3     ['1 Water Purifier', '12 Fan', '1 Exhaust Fan'...
# 4     ['11 Wardrobe', '13 Fan', '1 Exhaust Fan', '8 ...
# ...                                                 ...
# 1247  ['8 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1248  ['7 Fan', '1 Exhaust Fan', '5 Geyser', '1 Micr...
# 1249  ['4 Wardrobe', '7 Fan', '1 Exhaust Fan', '6 Ge...
# 1250  ['4 Wardrobe', '4 Geyser', '6 AC', '1 Modular ...
# 1251  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '5 Ge...
#
#                                                features
# 0     ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 1     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 2     ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 3     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 4     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# ...                                                 ...
# 1247  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1248  ['Security / Fire Alarm', 'Intercom Facility',...
# 1249  ['Security / Fire Alarm', 'Intercom Facility',...
# 1250  ['Water purifier', 'Centrally Air Conditioned'...
# 1251  ['Security / Fire Alarm', 'Private Garden / Te...
#
# [1252 rows x 17 columns]

# %% [markdown]
# #### 5. Balcony

# %%
column_cleaning['balcony'].unique()
# Out:
# array(['2 Balconies', '3+ Balconies', '3 Balconies', '1 Balcony',
#        'No Balcony'], dtype=object)

# %%
(column_cleaning['balcony']
            .str
            .split(" ")
            .str
            .get(0)
            .replace("No",0))
# Out:
# 0        2
# 1       3+
# 2        2
# 3        3
# 4        2
#         ..
# 1247     2
# 1248     3
# 1249    3+
# 1250     2
# 1251     3
# Name: balcony, Length: 1252, dtype: object

# %%
column_cleaning = (
    
    df_builder_floor
    
        .assign(
            price_in_cr = lambda df_: df_['price_in_cr']
                                        .str
                                        .replace('₹', '', regex=False)
                )

      
        .assign(
            price_in_cr = lambda df_: round(pd.to_numeric(df_['price_in_cr']
                                        .apply(lambda value: (float(str(value)
                                        .replace('Cr', '')
                                        .strip())
                                        if 'Cr' in str(value)
                                        else float(str(value)
                                        .replace('Lac', '')
                                        .strip()) / 100)
                                        if value not in ['Price on Request', None, np.nan] 
                                        else np.nan)),2)
                )

     
        .assign(
            price_per_sqft = lambda df_: pd.to_numeric(df_['price_per_sqft']
                                        .astype(str)
                                        .str
                                        .split("₹")
                                        .str
                                        .get(1)
                                        .str
                                        .replace("/sqft", "", regex=False)
                                        .str
                                        .replace(",", "", regex=False)
                                        .str
                                        .strip())
                
            ,
            bedrooms = lambda df_:df_['bedrooms']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
            ,
            bathrooms = lambda df_:df_['bathrooms']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
            ,
            balcony = lambda df_:df_['balcony']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
                                        .replace("No",0)
                
                
                )
)

column_cleaning
# Out:
#      property_id                                      property_name  \
# 0      O85021804  4 BHK Independent Builder Floor in Sushant Lok...
# 1      V85303340  4 BHK Independent Builder Floor in Sector 102,...
# 2      O83672012  4 BHK Independent Builder Floor in A Block Sus...
# 3      K85623978  4 BHK Independent Builder Floor in DLF Phase 2...
# 4      E85624224  4 BHK Independent Builder Floor in DLF Phase 2...
# ...          ...                                                ...
# 1247   G78860067  4 BHK Independent Builder Floor in Sector 46, ...
# 1248   S85218742  4 BHK Independent Builder Floor in Sushant Lok...
# 1249   R85216914  4 BHK Independent Builder Floor in Sushant Lok...
# 1250   B84531164  4 BHK Independent Builder Floor in Sector 84, ...
# 1251   F84618392  4 BHK Independent Builder Floor in Sector 63A,...
#
#                                                    link  \
# 0     https://www.99acres.com/4-bhk-bedroom-independ...
# 2     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 3     ['Gurgaon Central Mall', 'Hanuman Mandir', 'PV...
# 4     ['Gurgaon Central Mall', 'PVR Cinames', 'Priva...
# ...                                                 ...
# 1247  ['Dr. Aruna Kalra', 'Raheja Mall', 'Delhi Publ...
# 1248  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1249  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1250  ['Agri Business Management Collage', 'Manesar ...
# 1251  ['De Adventure Park', 'Vatika Business Centre'...
#
#                                      furnishing_details  \
# 0     ['1 Water Purifier', '6 Fan', '1 Exhaust Fan',...
# 1     ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 2     ['3 Fan', '1 Fridge', '5 Geyser', '1 Stove', '...
# 3     ['1 Water Purifier', '12 Fan', '1 Exhaust Fan'...
# 4     ['11 Wardrobe', '13 Fan', '1 Exhaust Fan', '8 ...
# ...                                                 ...
# 1247  ['8 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1248  ['7 Fan', '1 Exhaust Fan', '5 Geyser', '1 Micr...
# 1249  ['4 Wardrobe', '7 Fan', '1 Exhaust Fan', '6 Ge...
# 1250  ['4 Wardrobe', '4 Geyser', '6 AC', '1 Modular ...
# 1251  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '5 Ge...
#
#                                                features
# 0     ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 1     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 2     ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 3     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 4     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# ...                                                 ...
# 1247  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1248  ['Security / Fire Alarm', 'Intercom Facility',...
# 1249  ['Security / Fire Alarm', 'Intercom Facility',...
# 1250  ['Water purifier', 'Centrally Air Conditioned'...
# 1251  ['Security / Fire Alarm', 'Private Garden / Te...
#
# [1252 rows x 17 columns]

# %% [markdown]
# #### 6. AdditionalRoom

# %%
(column_cleaning['additional_room']
            .fillna('not available')
            .str
            .lower())
# Out:
# 0                                    servant room
# 1                                   not available
# 2                                      study room
# 3       pooja room,study room,servant room,others
# 4       pooja room,study room,servant room,others
#                           ...
# 1247                                 servant room
# 1248                                 servant room
# 1249                                 servant room
# 1250                                 servant room
# 1251                                 servant room
# Name: additional_room, Length: 1252, dtype: object

# %%
column_cleaning = (
    
    df_builder_floor
    
        .assign(
            price_in_cr = lambda df_: df_['price_in_cr']
                                        .str
                                        .replace('₹', '', regex=False)
                )

      
        .assign(
            price_in_cr = lambda df_: round(pd.to_numeric(df_['price_in_cr']
                                        .apply(lambda value: (float(str(value)
                                        .replace('Cr', '')
                                        .strip())
                                        if 'Cr' in str(value)
                                        else float(str(value)
                                        .replace('Lac', '')
                                        .strip()) / 100)
                                        if value not in ['Price on Request', None, np.nan] 
                                        else np.nan)),2)
                )

     
        .assign(
            price_per_sqft = lambda df_: pd.to_numeric(df_['price_per_sqft']
                                        .astype(str)
                                        .str
                                        .split("₹")
                                        .str
                                        .get(1)
                                        .str
                                        .replace("/sqft", "", regex=False)
                                        .str
                                        .replace(",", "", regex=False)
                                        .str
                                        .strip())
                
            ,
            bedrooms = lambda df_:df_['bedrooms']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
            ,
            bathrooms = lambda df_:df_['bathrooms']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
            ,
            balcony = lambda df_:df_['balcony']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
                                        .replace("No",0)
            ,
            additional_room = lambda df_: df_['additional_room']
                                        .fillna('not available')
                                        .str
                                        .lower()
                
                
                )
)

column_cleaning
# Out:
#      property_id                                      property_name  \
# 0      O85021804  4 BHK Independent Builder Floor in Sushant Lok...
# 1      V85303340  4 BHK Independent Builder Floor in Sector 102,...
# 2      O83672012  4 BHK Independent Builder Floor in A Block Sus...
# 3      K85623978  4 BHK Independent Builder Floor in DLF Phase 2...
# 4      E85624224  4 BHK Independent Builder Floor in DLF Phase 2...
# ...          ...                                                ...
# 1247   G78860067  4 BHK Independent Builder Floor in Sector 46, ...
# 1248   S85218742  4 BHK Independent Builder Floor in Sushant Lok...
# 1249   R85216914  4 BHK Independent Builder Floor in Sushant Lok...
# 1250   B84531164  4 BHK Independent Builder Floor in Sector 84, ...
# 1251   F84618392  4 BHK Independent Builder Floor in Sector 63A,...
#
#                                                    link  \
# 0     https://www.99acres.com/4-bhk-bedroom-independ...
# 1     https://www.99acres.com/4-bhk-bedroom-independ...
# 2     https://www.99acres.com/4-bhk-bedroom-independ...
# 3     https://www.99acres.com/4-bhk-bedroom-independ...
# 4     https://www.99acres.com/4-bhk-bedroom-independ...
# ...                                                 ...
# 1247  https://www.99acres.com/4-bhk-bedroom-independ...
# 1248  https://www.99acres.com/4-bhk-bedroom-independ...
# 1249  https://www.99acres.com/4-bhk-bedroom-independ...
# 1250  https://www.99acres.com/4-bhk-bedroom-independ...
# 1251  https://www.99acres.com/4-bhk-bedroom-independ...
#
#                                    society  price_in_cr  price_per_sqft  \
# 0                  Brand New Builder Floor         3.85           14259
# 1                            BPTP Amstoria         3.40           17000
# 2     A Block Sushant Lok Phase 1, Gurgaon         3.66           13811
# 3                     DLF Phase 2, Gurgaon         5.25           19444
# 4                        PARK FACING FLOOR         5.00           12500
# ...                                    ...          ...             ...
# 1247                 Private Builder Floor         3.00           10000
# 1248          Sushant Lok 1 Builder Floors         5.00           22727
# 1249          Sushant Lok Phase 1, Gurgaon         5.85           20892
# 1250                      SS Linden Floors         2.92           10428
# 1251                     Anant Raj Estates         3.80           15932
#
#                                   areawithtype bedrooms bathrooms balcony  \
# 0     2,700 sqft (251 sqm) Super Built-up Area        4         4       2
# 1             2,000 sqft (186 sqm) Carpet Area        4         4      3+
# 2     2,650 sqft (246 sqm) Super Built-up Area        4         4       2
# 3             2,700 sqft (251 sqm) Carpet Area        4         5       3
# 4             4,000 sqft (372 sqm) Carpet Area        4         5       2
# ...                                        ...      ...       ...     ...
# 1247  3,000 sqft (279 sqm) Super Built-up Area        4         4       2
# 1248          2,200 sqft (204 sqm) Carpet Area        4         4       3
# 1249          2,800 sqft (260 sqm) Carpet Area        4         4      3+
# 1250        2,800 sqft (260 sqm) Built-up Area        4         4       2
# 1251  2,385 sqft (222 sqm) Super Built-up Area        4         4       3
#
#                                 additional_room          floor_info  \
# 0                                  servant room   2nd   of 4 Floors
# 1                                 not available   1st   of 4 Floors
# 2                                    study room   1st   of 4 Floors
# 3     pooja room,study room,servant room,others   2nd   of 4 Floors
# 4     pooja room,study room,servant room,others   3rd   of 4 Floors
# ...                                         ...                 ...
# 1247                               servant room   1st   of 4 Floors
# 1248                               servant room  Ground of 4 Floors
# 1249                               servant room   2nd   of 4 Floors
# 1250                               servant room   2nd   of 4 Floors
# 1251                               servant room   4th   of 4 Floors
#
#           facing     property_age  \
# 0     North-East  0 to 1 Year Old
# 1     North-East  1 to 5 Year Old
# 2           East  1 to 5 Year Old
# 3           East  1 to 5 Year Old
# 4           East  0 to 1 Year Old
# ...          ...              ...
# 1247  North-East  0 to 1 Year Old
# 1248        West  0 to 1 Year Old
# 1249        East  0 to 1 Year Old
# 1250       North  0 to 1 Year Old
# 1251  North-East  0 to 1 Year Old
#
#                                         nearby_location  \
# 0     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 1     ['Conscient One Mall', "Domino's Pizza", 'Daul...
# 2     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 3     ['Gurgaon Central Mall', 'Hanuman Mandir', 'PV...
# 4     ['Gurgaon Central Mall', 'PVR Cinames', 'Priva...
# ...                                                 ...
# 1247  ['Dr. Aruna Kalra', 'Raheja Mall', 'Delhi Publ...
# 1248  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1249  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1250  ['Agri Business Management Collage', 'Manesar ...
# 1251  ['De Adventure Park', 'Vatika Business Centre'...
#
#                                      furnishing_details  \
# 0     ['1 Water Purifier', '6 Fan', '1 Exhaust Fan',...
# 1     ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 2     ['3 Fan', '1 Fridge', '5 Geyser', '1 Stove', '...
# 3     ['1 Water Purifier', '12 Fan', '1 Exhaust Fan'...
# 4     ['11 Wardrobe', '13 Fan', '1 Exhaust Fan', '8 ...
# ...                                                 ...
# 1247  ['8 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1248  ['7 Fan', '1 Exhaust Fan', '5 Geyser', '1 Micr...
# 1249  ['4 Wardrobe', '7 Fan', '1 Exhaust Fan', '6 Ge...
# 1250  ['4 Wardrobe', '4 Geyser', '6 AC', '1 Modular ...
# 1251  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '5 Ge...
#
#                                                features
# 0     ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 1     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 2     ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 3     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 4     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# ...                                                 ...
# 1247  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1248  ['Security / Fire Alarm', 'Intercom Facility',...
# 1249  ['Security / Fire Alarm', 'Intercom Facility',...
# 1250  ['Water purifier', 'Centrally Air Conditioned'...
# 1251  ['Security / Fire Alarm', 'Private Garden / Te...
#
# [1252 rows x 17 columns]

# %%
column_cleaning['additional_room'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 7. Facing

# %%
column_cleaning['facing']
# Out:
# 0       North-East
# 1       North-East
# 2             East
# 3             East
# 4             East
#            ...
# 1247    North-East
# 1248          West
# 1249          East
# 1250         North
# 1251    North-East
# Name: facing, Length: 1252, dtype: object

# %%
column_cleaning['facing'].value_counts()
# Out:
# facing
# East          401
# North-East    303
# North         179
# West          115
# North-West     65
# South-East     52
# South          46
# South-West     24
# Name: count, dtype: int64

# %%
column_cleaning['facing'].isnull().sum()
# Out:
# np.int64(67)

# %%
(column_cleaning['facing']
                                .fillna("Not Available")
                                .str
                                .lower())
# Out:
# 0       north-east
# 1       north-east
# 2             east
# 3             east
# 4             east
#            ...
# 1247    north-east
# 1248          west
# 1249          east
# 1250         north
# 1251    north-east
# Name: facing, Length: 1252, dtype: object

# %%
column_cleaning = (
    
    df_builder_floor
    
        .assign(
            price_in_cr = lambda df_: df_['price_in_cr']
                                        .str
                                        .replace('₹', '', regex=False)
                )

      
        .assign(
            price_in_cr = lambda df_: round(pd.to_numeric(df_['price_in_cr']
                                        .apply(lambda value: (float(str(value)
                                        .replace('Cr', '')
                                        .strip())
                                        if 'Cr' in str(value)
                                        else float(str(value)
                                        .replace('Lac', '')
                                        .strip()) / 100)
                                        if value not in ['Price on Request', None, np.nan] 
                                        else np.nan)),2)
                )

     
        .assign(
            price_per_sqft = lambda df_: pd.to_numeric(df_['price_per_sqft']
                                        .astype(str)
                                        .str
                                        .split("₹")
                                        .str
                                        .get(1)
                                        .str
                                        .replace("/sqft", "", regex=False)
                                        .str
                                        .replace(",", "", regex=False)
                                        .str
                                        .strip())
                
            ,
            bedrooms = lambda df_:df_['bedrooms']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
            ,
            bathrooms = lambda df_:df_['bathrooms']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
            ,
            balcony = lambda df_:df_['balcony']
                                        .str
                                        .split(" ")
                                        .str
                                        .get(0)
                                        .replace("No",0)
            ,
            additional_room = lambda df_: df_['additional_room']
                                        .fillna('not available')
                                        .str
                                        .lower()
            ,
            facing = lambda df_:df_['facing']
                                        .fillna("not available")
                                        .str
                                        .lower()
            )

)


column_cleaning
# Out:
#      property_id                                      property_name  \
# 0      O85021804  4 BHK Independent Builder Floor in Sushant Lok...
# 1      V85303340  4 BHK Independent Builder Floor in Sector 102,...
# 1251                               servant room   4th   of 4 Floors
#
#           facing     property_age  \
# 0     north-east  0 to 1 Year Old
# 1     north-east  1 to 5 Year Old
# 2           east  1 to 5 Year Old
# 3           east  1 to 5 Year Old
# 4           east  0 to 1 Year Old
# ...          ...              ...
# 1247  north-east  0 to 1 Year Old
# 1248        west  0 to 1 Year Old
# 1249        east  0 to 1 Year Old
# 1250       north  0 to 1 Year Old
# 1251  north-east  0 to 1 Year Old
#
#                                         nearby_location  \
# 0     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 1     ['Conscient One Mall', "Domino's Pizza", 'Daul...
# 2     ['Bahrisons library', 'Hanuman Mandir', 'New L...
# 3     ['Gurgaon Central Mall', 'Hanuman Mandir', 'PV...
# 4     ['Gurgaon Central Mall', 'PVR Cinames', 'Priva...
# ...                                                 ...
# 1247  ['Dr. Aruna Kalra', 'Raheja Mall', 'Delhi Publ...
# 1248  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1249  ['Kotak mahindra bank ATM', 'CCD', 'Belgian Wa...
# 1250  ['Agri Business Management Collage', 'Manesar ...
# 1251  ['De Adventure Park', 'Vatika Business Centre'...
#
#                                      furnishing_details  \
# 0     ['1 Water Purifier', '6 Fan', '1 Exhaust Fan',...
# 1     ['4 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 2     ['3 Fan', '1 Fridge', '5 Geyser', '1 Stove', '...
# 3     ['1 Water Purifier', '12 Fan', '1 Exhaust Fan'...
# 4     ['11 Wardrobe', '13 Fan', '1 Exhaust Fan', '8 ...
# ...                                                 ...
# 1247  ['8 Wardrobe', '1 Water Purifier', '12 Fan', '...
# 1248  ['7 Fan', '1 Exhaust Fan', '5 Geyser', '1 Micr...
# 1249  ['4 Wardrobe', '7 Fan', '1 Exhaust Fan', '6 Ge...
# 1250  ['4 Wardrobe', '4 Geyser', '6 AC', '1 Modular ...
# 1251  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '5 Ge...
#
#                                                features
# 0     ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 1     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 2     ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 3     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# 4     ['Feng Shui / Vaastu Compliant', 'Water purifi...
# ...                                                 ...
# 1247  ['Water purifier', 'Security / Fire Alarm', 'F...
# 1248  ['Security / Fire Alarm', 'Intercom Facility',...
# 1249  ['Security / Fire Alarm', 'Intercom Facility',...
# 1250  ['Water purifier', 'Centrally Air Conditioned'...
# 1251  ['Security / Fire Alarm', 'Private Garden / Te...
#
# [1252 rows x 17 columns]

# %%
column_cleaning.isnull().sum()
# Out:
# property_id            0
# property_name          0
# link                   0
# society                0
# price_in_cr            0
# price_per_sqft         0
# areawithtype           0
# bedrooms               0
# bathrooms              0
# balcony                0
# additional_room        0
# floor_info             0
# facing                 0
# property_age           1
# nearby_location        0
# furnishing_details    72
# features              38
# dtype: int64
