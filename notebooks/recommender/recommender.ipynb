# %% [markdown]
# # 🔎 Recommender Module — Society Similarity Engine
#
# **Goal.** Given a society/project, recommend the most similar societies — content-based, no user
# history. Three-engine design, built on the new 39k-listing pipeline:
#
# | Engine | Signal | Weight |
# |---|---|---|
# | **Facilities** | TF-IDF over each society's amenities (`features`) | **30** |
# | **Price** | Society price/area/BHK profile | **20** |
# | **Location** | Engineered `dist_to_*` geo features | **8** |
#
# **Self-contained.** No `src` imports, no file logging. Reads `data/fe/featured_properties.csv`,
# applies the same outlier rules as the model (inlined), and writes all artifacts to
# `data/recommender/`.

# %%
import ast, os, pickle
import numpy as np
import pandas as pd
import plotly.express as px
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler, MinMaxScaler

pd.set_option('display.max_columns', None)
OUTPUT_DIR = '../../data/recommender'
MIN_LISTINGS = 5
WEIGHTS = {'facilities': 30, 'price': 20, 'location': 8}

# %% [markdown]
# ## 1. Load & clean, restrict to real societies
#
# Outlier rules mirror `src/data_preprocessing/pre_process_data.py` (inlined for standalone use).

# %%
AREA_MIN = 180
AREA_CAP = {'Flat': 16000, 'Independent Builder Floor': 10000, 'Independent House': 30000}
PPSF_MIN, PPSF_MAX = 1500, 250000
MIN_AREA_PER_BEDROOM = 150

def parse_features(v):
    if pd.isna(v):
        return []
    try:
        x = ast.literal_eval(v)
        return [str(a).strip() for a in x] if isinstance(x, list) else []
    except (ValueError, SyntaxError):
        return []

df = pd.read_csv('../../data/fe/featured_properties.csv')
df = df[(df['area'] >= AREA_MIN) & (df['area'] <= df['property_type'].map(AREA_CAP))]
df = df[(df['price_in_cr'] * 1e7 / df['area']).between(PPSF_MIN, PPSF_MAX)]
df = df[(df['area'] / df['bedRoom']) >= MIN_AREA_PER_BEDROOM]

df['society'] = df['society'].replace('', np.nan)
df = df[df['society'].notna() & (df['society'].str.lower() != 'other')].copy()
df['features_list'] = df['features'].apply(parse_features)

counts = df['society'].value_counts()
df = df[df['society'].isin(counts[counts >= MIN_LISTINGS].index)].reset_index(drop=True)
societies = sorted(df['society'].unique())
society_index = {s: i for i, s in enumerate(societies)}
print(f'listings kept: {len(df):,} | societies: {len(societies)} (>= {MIN_LISTINGS} listings each)')

# %% [markdown]
# > **Conclusion.** ~660 societies with stable multi-listing profiles — a broad, high-quality
# > catalogue, all from the same clean data the price model uses.

# %% [markdown]
# ## 2. Engine 1 — Facilities similarity (weight 30)

# %%
fac = df.groupby('society')['features_list'].sum().reindex(societies)
fac_str = fac.apply(lambda lst: ' '.join(str(a) for a in lst) if isinstance(lst, list) else '')
tfidf = TfidfVectorizer(stop_words='english', ngram_range=(1, 2))
cosine_sim_features = cosine_similarity(tfidf.fit_transform(fac_str.values))
print('facilities:', cosine_sim_features.shape, '| vocab', len(tfidf.vocabulary_))

# %% [markdown]
# > **Conclusion.** TF-IDF down-weights near-universal amenities (AC, power backup, Vaastu) and
# > lets rarer, discriminating ones (club, pool, servant room) drive similarity.

# %% [markdown]
# ## 3. Engine 2 — Price similarity (weight 20)

# %%
price_df = (df.groupby('society')
              .agg(min_price_cr=('price_in_cr', 'min'), max_price_cr=('price_in_cr', 'max'),
                   avg_price_cr=('price_in_cr', 'mean'), min_area_sqft=('area', 'min'),
                   max_area_sqft=('area', 'max'), avg_area_sqft=('area', 'mean'),
                   min_bhk=('bedRoom', 'min'), max_bhk=('bedRoom', 'max')).reindex(societies))
price_df['property_type'] = (df.groupby('society')['property_type']
                               .agg(lambda x: x.mode().iloc[0]).reindex(societies))
price_df[['avg_price_cr', 'avg_area_sqft']] = price_df[['avg_price_cr', 'avg_area_sqft']].round(2)

NUM = ['min_price_cr', 'max_price_cr', 'avg_price_cr', 'min_area_sqft', 'max_area_sqft',
       'avg_area_sqft', 'min_bhk', 'max_bhk']
model = price_df.copy(); model[NUM] = np.log1p(model[NUM])
model = pd.get_dummies(model, columns=['property_type'], drop_first=True).fillna(0)
cosine_sim_price = cosine_similarity(StandardScaler().fit_transform(model))
print('price:', cosine_sim_price.shape)
price_df.head(3)

# %% [markdown]
# > **Conclusion.** Societies sit near others in the same price/size/format band — a ₹5 Cr luxury
# > tower matches other luxury towers, not budget floors. Log-scaling tames the luxury tail.

# %% [markdown]
# ## 4. Engine 3 — Location similarity (weight 8)

# %%
DIST = ['dist_to_cyber_city', 'dist_to_golf_road', 'dist_to_airport', 'dist_to_manesar']
location_df = df.groupby('society')[DIST].median().reindex(societies)
location_df = location_df.fillna(location_df.median())
cosine_sim_location = cosine_similarity(MinMaxScaler().fit_transform(location_df))
print('location:', cosine_sim_location.shape)

# %% [markdown]
# > **Conclusion.** Groups societies by where they sit in the city — the Golf-Course-Road luxury
# > corridor clusters together, New-Gurgaon clusters together — reusing the model's top features.

# %% [markdown]
# ## 5. Combine & recommend

# %%
cosine_sim_combined = (WEIGHTS['facilities'] * cosine_sim_features +
                       WEIGHTS['price'] * cosine_sim_price +
                       WEIGHTS['location'] * cosine_sim_location)

def recommend(name, top_n=10):
    idx = society_index[name]
    scores = sorted(enumerate(cosine_sim_combined[idx]), key=lambda x: x[1], reverse=True)[1:top_n + 1]
    rows = []
    for i, sc in scores:
        s = societies[i]
        rows.append({'Society': s, 'Similarity': round(float(sc), 2),
                     'AvgPrice_Cr': price_df.loc[s, 'avg_price_cr'],
                     'AvgArea': int(price_df.loc[s, 'avg_area_sqft']),
                     'BHK': f"{int(price_df.loc[s, 'min_bhk'])}-{int(price_df.loc[s, 'max_bhk'])}"})
    return pd.DataFrame(rows)

example = societies[0]
print('Top-10 similar to:', example)
recommend(example)

# %% [markdown]
# > **Conclusion.** Recommendations blend what a society offers (amenities), what it costs (price
# > band), and where it is (location) — genuine alternatives a buyer would shortlist.

# %% [markdown]
# ## 6. Validate — engine contribution

# %%
idx = society_index[example]
top = sorted(enumerate(cosine_sim_combined[idx]), key=lambda x: x[1], reverse=True)[1:11]
ti = [i for i, _ in top]
contrib = pd.DataFrame({'Facilities': cosine_sim_features[idx, ti], 'Price': cosine_sim_price[idx, ti],
                        'Location': cosine_sim_location[idx, ti]},
                       index=[societies[i] for i in ti]).round(2)
fig = px.imshow(contrib, text_auto=True, aspect='auto', color_continuous_scale='Blues',
                labels={'x': 'Engine (raw cosine)', 'y': 'Recommended society', 'color': 'Similarity'},
                title=f'Engine contribution for: {example}')
fig.update_layout(height=450)
fig

# %% [markdown]
# > **Conclusion.** Each recommendation draws on all three engines — facilities usually strongest,
# > price and location refine the ranking. The intended 30/20/8 balance holds.

# %% [markdown]
# ## 7. Save artifacts (drop-in for the Streamlit page)

# %%
os.makedirs(OUTPUT_DIR, exist_ok=True)
artifacts = {'location_distance.pkl': location_df, 'price_df.pkl': price_df,
             'cosine_sim_top_features.pkl': cosine_sim_features, 'cosine_sim_price.pkl': cosine_sim_price,
             'cosine_sim_location.pkl': cosine_sim_location}
for fname, obj in artifacts.items():
    with open(os.path.join(OUTPUT_DIR, fname), 'wb') as f:
        pickle.dump(obj, f)
    print('saved', fname)
print('societies:', len(societies))

# %% [markdown]
# ---
# ### Summary
# A three-engine, content-based recommender over **660 Gurgaon societies**: Facilities (TF-IDF, 30)
# + Price profile (20) + Location (engineered distances, 8). Artifacts in `data/recommender/` are
# consumed by `pages/Recommendation_Module.py`.
